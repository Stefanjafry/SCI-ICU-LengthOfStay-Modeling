# %% [markdown]
# ## SQL Queries Of MIMIC IV Database In Order To Create One Streamlined Table For EDA, and ML model Building

# %% [markdown]
# Introduction
# This notebook demonstrates an end-to-end SQL-driven data cleaning and transformation workflow applied to a real-world dataset. The project simulates a professional data wrangling task using PostgreSQL, where raw, messy tabular data is systematically normalized, standardized, and cleaned through a series of structured queries and procedural logic.
#
# Key aspects include:
#
# Exploratory Data Analysis (EDA) using SELECT, COUNT, and GROUP BY to identify inconsistencies and nulls
#
# Column-level standardization, including formatting dates, fixing case sensitivity, and splitting multi-value fields
#
# Null value handling through conditional logic and CASE statements
#
# Joins and CTEs (Common Table Expressions) to restructure tables and enrich the dataset
#
# Final output generation via materialized views or export-ready tables

# %%
# Template for a DATAFRAME.
# This function is used to provide basic Dataframe analysis to Explore data that can due utilized for exploring different tables;
# Help us better understand the different tables it's values and it usability for our study on Spinal Chord porject.

import pandas as pd

def explore_dataframe(df):
    """
    Explores and summarizes the given DataFrame.
    
    Parameters:
        df (DataFrame): The DataFrame to analyze.
        
    Returns:
        None
    """
    print("--------------- DataFrame Exploration Summary ---------------")

    # Basic Information and Records
    print("\nNumber of records (rows):", df.shape[0])  # Total number of rows
    print("Number of columns:", df.shape[1])  # Total number of columns
    print("\nColumn Names:")
    print(df.columns)  # List of column names

    # Preview the Data
    print("\nFirst 5 rows of the DataFrame:")
    print(df.head())  # Display the first 5 rows
    print("\nLast 5 rows of the DataFrame:")
    print(df.tail())  # Display the last 5 rows

    # Data Types and Structure
    print("\nInformation about DataFrame (columns and data types):")
    print(df.info())  # Information about columns, types, non-null values

    # Summary Statistics
    print("\nSummary statistics for numerical columns:")
    print(df.describe())  # Summary stats: count, mean, std, min, max, etc.

    # Check Missing Data
    print("\nNumber of missing (NaN) values per column:")
    print(df.isnull().sum())  # Count NaN values in each column

    # Count Non-Null Values in Each Column
    print("\nNumber of non-null (non-NaN) values per column:")
    print(df.count())  # Count of non-null values for each column

    # Unique Values in a Specific Column
    column_name = 'column_name_here'  # Replace with your column name
    if column_name in df.columns:
        print(f"\nUnique values in '{column_name}':")
        print(df[column_name].unique())  # Display unique values

    # Grouping Data
    # Example: Replace 'column_name' with the column to group by
    if 'column_name' in df.columns:
        grouped = df.groupby('column_name').size()  # Group and count
        print("\nGrouped Data (count per category):")
        print(grouped)

    # Filter Example
    # Example: Replace 'column_name' and 'specific_value' with your criteria
    if 'column_name' in df.columns:
        filtered_df = df[df['column_name'] == 'specific_value']
        print("\nFiltered DataFrame (example):")
        print(filtered_df)

    print("\n--------------- End of Exploration Summary ---------------")

# Example: Call this function on a DataFrame
# Assume `df` is your DataFrame
# explore_dataframe(df)

# %%
# Code to test SQL Lite for the first time to be able to write Standard SQL to review csv/compressed files. 
import pandas as pd
import sqlite3

# Read the .csv.gz file into a Pandas DataFrame
df = pd.read_csv("c:/stefan/icu/icustays.csv.gz")

# Connect to (or create) a database file
conn = sqlite3.connect("d:/mimic.db")

# Write the DataFrame to a SQL table
df.to_sql("icustays", conn, if_exists="replace", index=False)

# Run a SQL query

query = "SELECT * FROM icustays limit 5;"
result_df = pd.read_sql_query(query, conn)

# Display the query result
print(result_df)

conn.close()
# Out:
#    subject_id   hadm_id   stay_id  \
# 0    10000032  29079034  39553978
# 1    10000980  26913865  39765666
# 2    10001217  24597018  37067082
# 3    10001217  27703517  34592300
# 4    10001725  25563031  31205490
#
#                                      first_careunit  \
# 0                Medical Intensive Care Unit (MICU)
# 1                Medical Intensive Care Unit (MICU)
# 2               Surgical Intensive Care Unit (SICU)
# 3               Surgical Intensive Care Unit (SICU)
# 4  Medical/Surgical Intensive Care Unit (MICU/SICU)
#
#                                       last_careunit               intime  \
# 0                Medical Intensive Care Unit (MICU)  2180-07-23 14:00:00
# 1                Medical Intensive Care Unit (MICU)  2189-06-27 08:42:00
# 2               Surgical Intensive Care Unit (SICU)  2157-11-20 19:18:02
# 3               Surgical Intensive Care Unit (SICU)  2157-12-19 15:42:24
# 4  Medical/Surgical Intensive Care Unit (MICU/SICU)  2110-04-11 15:52:22
#
#                outtime       los
# 0  2180-07-23 23:50:47  0.410266
# 1  2189-06-27 20:38:27  0.497535
# 2  2157-11-21 22:08:00  1.118032
# 3  2157-12-20 14:27:41  0.948113
# 4  2110-04-12 23:59:56  1.338588

# %%
# In this example we are reviewing table loaded in chunks as the table is very largea us sql lite and chunks at a time.
import pandas as pd
import sqlite3

# Read the .csv.gz file in chunks using Pandas
chunksize = 10000
conn = sqlite3.connect("c:/Stefan/mimic.db")

for chunk in pd.read_csv("c:/stefan/icu/chartevents.csv.gz", compression='gzip', chunksize=chunksize):
    chunk.to_sql("chartevents", conn, if_exists="append", index=False)

# Query the database
query = "SELECT * FROM chartevents LIMIT 5;"
result_df = pd.read_sql_query(query, conn)
print(result_df)

conn.close()
# Out:
#    subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0    10000032  29079034  39553978       47007.0  2180-07-23 21:01:00
# 1    10000032  29079034  39553978       47007.0  2180-07-23 21:01:00
# 2    10000032  29079034  39553978       47007.0  2180-07-23 21:01:00
# 3    10000032  29079034  39553978       47007.0  2180-07-23 22:00:00
# 4    10000032  29079034  39553978       47007.0  2180-07-23 22:00:00
#
#              storetime  itemid value  valuenum valueuom  warning
# 0  2180-07-23 22:15:00  220179    82      82.0     mmHg      0.0
# 1  2180-07-23 22:15:00  220180    59      59.0     mmHg      0.0
# 2  2180-07-23 22:15:00  220181    63      63.0     mmHg      0.0
# 3  2180-07-23 22:15:00  220045    94      94.0      bpm      0.0
# 4  2180-07-23 22:15:00  220179    85      85.0     mmHg      0.0

# %%
# To show what exsits in the mimic.db (sqllite), all the table names.
# Please note that tables below in SQL Lite database is result table are all CAPITAL letters. 
# Simply put the mixed cases tables are all input tables where all CAP tables are result tables.
import pandas as pd
import sqlite3

# Connect to (or create) a database file
conn = sqlite3.connect("e:/mimic.db")

# Query to list all tables in the database
query = "SELECT name FROM sqlite_master WHERE type='table';"

# Commit the changes (optional but good practice)
conn.commit()

# Execute the query and display the results
tables_df = pd.read_sql_query(query, conn)
print(tables_df)

# Close the connection
conn.close()
# Out:
#                                  name
# 0                         chartevents
# 1                    Ingredientevents
# 2                         inputevents
# 3                        outputevents
# 4                     procedureevents
# 5                      datetimeevents
# 6                             d_items
# 7                            icustays
# 8                       diagnoses_icd
# 9                     d_icd_diagnoses
# 10                   d_icd_procedures
# 11                     procedures_icd
# 12                            patient
# 13                         admissions
# 14                          labevents
# 15                 microbiologyevents
# 16                    spinal_icd_list
# 17            ICU_SPINAL_PATIENT_5290
# 18        ICU_SPINAL_PATIENT_FEATURES
# 19                      caregiver.csv
# 20                          caregiver
# 21  ICU_SPINAL_PATIENT_FEATURES_CHART

# %%
# Run everytime; Loads tables in sqllite database. Created a function. At the bottom are many exmaples of the tables loaded,
# using the load_csv_to_sqlite function in chunks incase some of the table are very large.
import pandas as pd
import sqlite3

def load_csv_to_sqlite(file_path, db_path, table_name, chunksize=10000):
    """
    Loads a compressed .csv.gz file into a SQLite database table.

    Parameters:
    - file_path (str): Path to the .csv.gz file to be loaded.
    - db_path (str): Path to the SQLite database file.
    - table_name (str): Name of the table to write data to.
    - chunksize (int): Number of rows to process per chunk (default is 10000).
    """
    try:
        # Connect to (or create) the SQLite database
        conn = sqlite3.connect(db_path)

        # Read the .csv.gz file in chunks and write to the database
        for chunk in pd.read_csv(file_path, compression='gzip', chunksize=chunksize):
            chunk.to_sql(table_name, conn, if_exists="append", index=False)

        # Query the database to confirm data has been written
        query = f"SELECT * FROM {table_name} LIMIT 5;"
        result_df = pd.read_sql_query(query, conn)
        print(result_df)

        # Close the connection
        conn.close()
        print(f"Data from {file_path} has been successfully loaded into the {table_name} table!")
    except Exception as e:
        print(f"An error occurred: {e}")


"""
load_csv_to_sqlite(
    file_path="c:/stefan/icu/Ingredientevents.csv.gz",
    db_path="e:/mimic.db",
    table_name="Ingredientevents"
)

load_csv_to_sqlite(
    file_path="c:/stefan/icu/inputevents.csv.gz",
    db_path="e:/mimic.db",
    table_name="inputevents"
)

load_csv_to_sqlite(
    file_path="c:/stefan/icu/outputevents.csv.gz",
    db_path="e:/mimic.db",
    table_name="outputevents"
)

load_csv_to_sqlite(
    file_path="c:/stefan/icu/procedureevents.csv.gz",
    db_path="e:/mimic.db",
    table_name="procedureevents"
)

load_csv_to_sqlite(
    file_path="c:/stefan/icu/datetimeevents.csv.gz",
    db_path="e:/mimic.db",
    table_name="datetimeevents"
)

load_csv_to_sqlite(
    file_path="c:/stefan/icu/d_items.csv.gz",
    db_path="e:/mimic.db",
    table_name="d_items"
)

"""
# Out:
# '\nload_csv_to_sqlite(\n    file_path="c:/stefan/icu/Ingredientevents.csv.gz",\n    db_path="e:/mimic.db",\n    table_name="Ingredientevents"\n)\n\nload_csv_to_sqlite(\n    file_path="c:/stefan/icu/inputevents.csv.gz",\n    db_path="e:/mimic.db",\n    table_name="inputevents"\n)\n\nload_csv_to_sqlite(\n    file_path="c:/stefan/icu/outputevents.csv.gz",\n    db_path="e:/mimic.db",\n    table_name="outputevents"\n)\n\nload_csv_to_sqlite(\n    file_path="c:/stefan/icu/procedureevents.csv.gz",\n    db_path="e:/mimic.db",\n    table_name="procedureevents"\n)\n\nload_csv_to_sqlite(\n    file_path="c:/stefan/icu/datetimeevents.csv.gz",\n    db_path="e:/mimic.db",\n    table_name="datetimeevents"\n)\n\nload_csv_to_sqlite(\n    file_path="c:/stefan/icu/d_items.csv.gz",\n    db_path="e:/mimic.db",\n    table_name="d_items"\n)\n\n'

# %%
# Belose are queryies we ran to see Query to figure out table information and which table we can take advantage of in order 
# to realize tables to include.


# Connect to (or create) a database file (SQL LITE database which will contain all input and output file. To utilize SQL.
# Name is mimic.db.
conn = sqlite3.connect("e:/mimic.db")

# Run a SQL query

query = "SELECT * FROM diagnoses_icd WHERE icd_code LIKE '806%';"
query1 = "SELECT distinct * FROM d_icd_diagnoses WHERE icd_code LIKE '806%';"
query2 = "SELECT * FROM d_icd_procedures WHERE icd_code LIKE '806%';"
query3 = "SELECT * FROM procedures_icd WHERE icd_code LIKE '806%';"
query4 = "select distinct(icd_code) from diagnoses_icd where icd_code LIKE '806%' order by 1;"

#SELECT * FROM diagnosis_icd where icd_code  limit 5;"
result_df4 = pd.read_sql_query(query4, conn)
result_df = pd.read_sql_query(query, conn)
result_df1 = pd.read_sql_query(query1, conn)
result_df2 = pd.read_sql_query(query2, conn) 
result_df3 = pd.read_sql_query(query3, conn)

# Display the query result
print(result_df4)
print(result_df)
print(result_df1)
print(result_df2)
print(result_df3)
conn.close()
# Out:
#    icd_code
# 0     80600
# 1     80601
# 2     80602
# 3     80603
# 4     80604
# 5     80605
# 6     80606
# 7     80607
# 8     80608
# 9     80609
# 10    80610
# 11    80613
# 12    80620
# 13    80621
# 14    80623
# 15    80624
# 16    80625
# 17    80626
# 18    80629
# 19    80639
# 20     8064
# 21     8065
# 22    80660
# 23    80662
# 24     8068
#      subject_id   hadm_id  seq_num icd_code  icd_version
# 0      10035747  27083519        3    80610            9
# 1      10196368  24464472        1    80604            9
# 2      10229323  25045444       22     8064            9
# 3      10275408  20562387        1    80603            9
# 4      10275408  20562387        4    80608            9
# ..          ...       ...      ...      ...          ...
# 270    19953811  29850814        2    80624            9
# 271    19964212  26401796        1    80620            9
# 272    19970947  28546800        1    80600            9
# 273    19970947  28546800        2    80620            9
# 274    19970947  28546800        3    80605            9
#
# [275 rows x 5 columns]
#     icd_code  icd_version                                         long_title
# 0      80600            9  Closed fracture of C1-C4 level with unspecifie...
# 1      80601            9  Closed fracture of C1-C4 level with complete l...
# 2      80602            9  Closed fracture of C1-C4 level with anterior c...
# 3      80603            9  Closed fracture of C1-C4 level with central co...
# 4      80604            9  Closed fracture of C1-C4 level with other spec...
# 5      80605            9  Closed fracture of C5-C7 level with unspecifie...
# 6      80606            9  Closed fracture of C5-C7 level with complete l...
# 7      80607            9  Closed fracture of C5-C7 level with anterior c...
# 8      80608            9  Closed fracture of C5-C7 level with central co...
# 9      80609            9  Closed fracture of C5-C7 level with other spec...
# 10     80610            9  Open fracture of C1-C4 level with unspecified ...
# 11     80611            9  Open fracture of C1-C4 level with complete les...
# 12     80612            9  Open fracture of C1-C4 level with anterior cor...
# 13     80613            9  Open fracture of C1-C4 level with central cord...
# 14     80614            9  Open fracture of C1-C4 level with other specif...
# 15     80615            9  Open fracture of C5-C7 level with unspecified ...
# 16     80616            9  Open fracture of C5-C7 level with complete les...
# 17     80617            9  Open fracture of C5-C7 level with anterior cor...
# 18     80618            9  Open fracture of C5-C7 level with central cord...
# 19     80619            9  Open fracture of C5-C7 level with other specif...
# 20     80620            9  Closed fracture of T1-T6 level with unspecifie...
# 21     80621            9  Closed fracture of T1-T6 level with complete l...
# 22     80622            9  Closed fracture of T1-T6 level with anterior c...
# 23     80623            9  Closed fracture of T1-T6 level with central co...
# 24     80624            9  Closed fracture of T1-T6 level with other spec...
# 25     80625            9  Closed fracture of T7-T12 level with unspecifi...
# 26     80626            9  Closed fracture of T7-T12 level with complete ...
# 27     80627            9  Closed fracture of T7-T12 level with anterior ...
# 28     80628            9  Closed fracture of T7-T12 level with central c...
# 29     80629            9  Closed fracture of T7-T12 level with other spe...
# 30     80630            9  Open fracture of T1-T6 level with unspecified ...
# 31     80631            9  Open fracture of T1-T6 level with complete les...
# 32     80632            9  Open fracture of T1-T6 level with anterior cor...
# 33     80633            9  Open fracture of T1-T6 level with central cord...
# 34     80634            9  Open fracture of T1-T6 level with other specif...
# 35     80635            9  Open fracture of T7-T12 level with unspecified...
# 36     80636            9  Open fracture of T7-T12 level with complete le...
# 37     80637            9  Open fracture of T7-T12 level with anterior co...
# 38     80638            9  Open fracture of T7-T12 level with central cor...
# 39     80639            9  Open fracture of T7-T12 level with other speci...
# 40      8064            9  Closed fracture of lumbar spine with spinal co...
# 41      8065            9  Open fracture of lumbar spine with spinal cord...
# 42     80660            9  Closed fracture of sacrum and coccyx with unsp...
# 43     80661            9  Closed fracture of sacrum and coccyx with comp...
# 44     80662            9  Closed fracture of sacrum and coccyx with othe...
# 45     80669            9  Closed fracture of sacrum and coccyx with othe...
# 46     80670            9  Open fracture of sacrum and coccyx with unspec...
# 47     80671            9  Open fracture of sacrum and coccyx with comple...
# 48     80672            9  Open fracture of sacrum and coccyx with other ...
# 49     80679            9  Open fracture of sacrum and coccyx with other ...
# 50      8068            9  Closed fracture of unspecified vertebral colum...
# 51      8069            9  Open fracture of unspecified vertebral column ...
#   icd_code  icd_version                               long_title
# 0      806            9  Excision of semilunar cartilage of knee
#     subject_id   hadm_id  seq_num   chartdate icd_code  icd_version
# 0     10007920  23967347        1  2135-11-29      806            9
# 1     10115962  22611783        3  2124-05-15      806            9
# 2     10119906  21155726        2  2161-05-28      806            9
# 3     10210315  27153320        1  2166-03-06      806            9
# 4     10373619  23912250        1  2127-05-03      806            9
# ..         ...       ...      ...         ...      ...          ...
# 65    19339541  24623866        3  2161-10-26      806            9
# 66    19431901  23656057        1  2138-10-11      806            9
# 67    19584529  24099643        2  2168-08-23      806            9
# 68    19683696  21948379        2  2167-03-11      806            9
# 69    19943967  28933381        4  2150-08-15      806            9
#
# [70 rows x 6 columns]

# %%
# Verification query of icd codes; ALL the Spinal realted icd_code (1136 Observations discovered).
# First driving table, to filter out the Spinal related injuries/issues.
query = """
SELECT
    icd_code,
    long_title
FROM
    d_icd_diagnoses
WHERE
    LOWER(long_title) LIKE '%spinal%'
    OR LOWER(long_title) LIKE '%spine%'
    OR LOWER(long_title) LIKE '%vertebral%'
ORDER BY
    icd_code;
"""
pd.set_option('display.max_rows', None)
result = execute_sql("e:/mimic.db", query)
if result is not None:
    print(result)
# Out:
# --------------- DataFrame Exploration Summary ---------------
#
# Number of records (rows): 1136
# Number of columns: 2
#
# Column Names:
# Index(['icd_code', 'long_title'], dtype='object')
#
# First 5 rows of the DataFrame:
#   icd_code                                         long_title
# 0     1340            Tuberculoma of spinal cord, unspecified
# 1     1341  Tuberculoma of spinal cord, bacteriological or...
# 2     1342  Tuberculoma of spinal cord, bacteriological or...
# 3     1343  Tuberculoma of spinal cord, tubercle bacilli f...
# 4     1344  Tuberculoma of spinal cord, tubercle bacilli n...
#
# Last 5 rows of the DataFrame:
#      icd_code                                         long_title
# 1131  W60XXXD  Contact with nonvenomous plant thorns and spin...
# 1132  W60XXXS  Contact with nonvenomous plant thorns and spin...
# 1133    Z1831                   Retained animal quills or spines
# 1134    Z4541  Encounter for adjustment and management of cer...
# 1135     Z982    Presence of cerebrospinal fluid drainage device
#
# Information about DataFrame (columns and data types):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1136 entries, 0 to 1135
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   icd_code    1136 non-null   object
#  1   long_title  1136 non-null   object
# dtypes: object(2)
# memory usage: 17.9+ KB
# None
#
# Summary statistics for numerical columns:
#        icd_code                             long_title
# count      1136                                   1136
# unique     1136                                   1117
# top     T85733A  Other recurrent vertebral dislocation
# freq          1                                      2
#
# Number of missing (NaN) values per column:
# icd_code      0
# long_title    0
# dtype: int64
#
# Number of non-null (non-NaN) values per column:
# icd_code      1136
# long_title    1136
# dtype: int64
#
# --------------- End of Exploration Summary ---------------
#      icd_code                                         long_title
# 0        1340            Tuberculoma of spinal cord, unspecified
# 1        1341  Tuberculoma of spinal cord, bacteriological or...
# 2        1342  Tuberculoma of spinal cord, bacteriological or...
# 3        1343  Tuberculoma of spinal cord, tubercle bacilli f...
# 4        1344  Tuberculoma of spinal cord, tubercle bacilli n...
# 5        1345  Tuberculoma of spinal cord, tubercle bacilli n...
# 6        1346  Tuberculoma of spinal cord, tubercle bacilli n...
# 7        1350    Tuberculous abscess of spinal cord, unspecified
# 8        1351  Tuberculous abscess of spinal cord, bacteriolo...
# 9        1352  Tuberculous abscess of spinal cord, bacteriolo...
# 10       1353  Tuberculous abscess of spinal cord, tubercle b...
# 11       1354  Tuberculous abscess of spinal cord, tubercle b...
# 12       1355  Tuberculous abscess of spinal cord, tubercle b...
# 13       1356  Tuberculous abscess of spinal cord, tubercle b...
# 14       1500      Tuberculosis of vertebral column, unspecified
# 15       1501  Tuberculosis of vertebral column, bacteriologi...
# 16       1502  Tuberculosis of vertebral column, bacteriologi...
# 17       1503  Tuberculosis of vertebral column, tubercle bac...
# 18       1504  Tuberculosis of vertebral column, tubercle bac...
# 19       1505  Tuberculosis of vertebral column, tubercle bac...
# 20       1506  Tuberculosis of vertebral column, tubercle bac...
# 21       1702  Malignant neoplasm of vertebral column, exclud...
# 22       1922                  Malignant neoplasm of spinal cord
# 23       1923              Malignant neoplasm of spinal meninges
# 24       1983  Secondary malignant neoplasm of brain and spin...
# 25       2132  Benign neoplasm of vertebral column, excluding...
# 26       2253                     Benign neoplasm of spinal cord
# 27       2254                 Benign neoplasm of spinal meninges
# 28       2375  Neoplasm of uncertain behavior of brain and sp...
# 29       3241                                Intraspinal abscess
# 30       3249  Intracranial and intraspinal abscess of unspec...
# 31       3362  Subacute combined degeneration of spinal cord ...
# 32       3369                 Unspecified disease of spinal cord
# 33       3490              Reaction to spinal or lumbar puncture
# 34       4351                          Vertebral artery syndrome
# 35       7201                                Spinal enthesopathy
# 36       7215                                      Kissing spine
# 37       7216                  Ankylosing vertebral hyperostosis
# 38       7218                    Other allied disorders of spine
# 39       7220  Displacement of cervical intervertebral disc w...
# 40       7222  Displacement of intervertebral disc, site unsp...
# 41       7224       Degeneration of cervical intervertebral disc
# 42       7226  Degeneration of intervertebral disc, site unsp...
# 43       7230                 Spinal stenosis in cervical region
# 44       7241                             Pain in thoracic spine
# 45       7320                  Juvenile osteochondrosis of spine
# 46       7378                          Other curvatures of spine
# 47       7379                     Unspecified curvature of spine
# 48       7385          Other acquired deformity of back or spine
# 49       7429  Unspecified congenital anomaly of brain, spina...
# 50       7542    Congenital musculoskeletal deformities of spine
# 51       7674  Injury to spine and spinal cord due to birth t...
# 52       7920  Nonspecific abnormal findings in cerebrospinal...
# 53       8052  Closed fracture of dorsal [thoracic] vertebra ...
# 54       8053  Open fracture of dorsal [thoracic] vertebra wi...
# 55       8054  Closed fracture of lumbar vertebra without men...
# 56       8055  Open fracture of lumbar vertebra without menti...
# 57       8056  Closed fracture of sacrum and coccyx without m...
# 58       8057  Open fracture of sacrum and coccyx without men...
# 59       8058  Closed fracture of unspecified vertebral colum...
# 60       8059  Open fracture of unspecified vertebral column ...
# 61       8064  Closed fracture of lumbar spine with spinal co...
# 62       8065  Open fracture of lumbar spine with spinal cord...
# 63       8068  Closed fracture of unspecified vertebral colum...
# 64       8069  Open fracture of unspecified vertebral column ...
# 65       9051  Late effect of fracture of spine and trunk wit...
# 66       9072                  Late effect of spinal cord injury
# 67       9073  Late effect of injury to nerve root(s), spinal...
# 68       9522  Lumbar spinal cord injury without evidence of ...
# 69       9523  Sacral spinal cord injury without evidence of ...
# 70       9524  Cauda equina spinal cord injury without eviden...
# 71       9528  Multiple sites of spinal cord injury without e...
# 72       9529  Unspecified site of spinal cord injury without...
# 73       9538  Injury to multiple sites of nerve roots and sp...
# 74       9539  Injury to unspecified site of nerve roots and ...
# 75       9687                    Poisoning by spinal anesthetics
# 76      33510               Spinal muscular atrophy, unspecified
# 77      33519                      Other spinal muscular atrophy
# 78      34981                     Cerebrospinal fluid rhinorrhea
# 79      38861                       Cerebrospinal fluid otorrhea
# 80      43320  Occlusion and stenosis of vertebral artery wit...
# 81      43321  Occlusion and stenosis of vertebral artery wit...
# 82      44324                     Dissection of vertebral artery
# 83      72210  Displacement of lumbar intervertebral disc wit...
# 84      72211  Displacement of thoracic intervertebral disc w...
# 85      72251  Degeneration of thoracic or thoracolumbar inte...
# 86      72252  Degeneration of lumbar or lumbosacral interver...
# 87      72270  Intervertebral disc disorder with myelopathy, ...
# 88      72271  Intervertebral disc disorder with myelopathy, ...
# 89      72272  Intervertebral disc disorder with myelopathy, ...
# 90      72273  Intervertebral disc disorder with myelopathy, ...
# 91      72400                Spinal stenosis, unspecified region
# 92      72401                   Spinal stenosis, thoracic region
# 93      72402  Spinal stenosis, lumbar region, without neurog...
# 94      72403  Spinal stenosis, lumbar region, with neurogeni...
# 95      72409                      Spinal stenosis, other region
# 96      73740  Curvature of spine, unspecified, associated wi...
# 97      74259  Other specified congenital anomalies of spinal...
# 98      74782                              Spinal vessel anomaly
# 99      75610                      Anomaly of spine, unspecified
# 100     75615             Fusion of spine (vertebra), congenital
# 101     75619                           Other anomalies of spine
# 102     80600  Closed fracture of C1-C4 level with unspecifie...
# 103     80604  Closed fracture of C1-C4 level with other spec...
# 104     80605  Closed fracture of C5-C7 level with unspecifie...
# 105     80609  Closed fracture of C5-C7 level with other spec...
# 106     80610  Open fracture of C1-C4 level with unspecified ...
# 107     80614  Open fracture of C1-C4 level with other specif...
# 108     80615  Open fracture of C5-C7 level with unspecified ...
# 109     80619  Open fracture of C5-C7 level with other specif...
# 110     80620  Closed fracture of T1-T6 level with unspecifie...
# 111     80624  Closed fracture of T1-T6 level with other spec...
# 112     80625  Closed fracture of T7-T12 level with unspecifi...
# 113     80629  Closed fracture of T7-T12 level with other spe...
# 114     80630  Open fracture of T1-T6 level with unspecified ...
# 115     80634  Open fracture of T1-T6 level with other specif...
# 116     80635  Open fracture of T7-T12 level with unspecified...
# 117     80639  Open fracture of T7-T12 level with other speci...
# 118     80660  Closed fracture of sacrum and coccyx with unsp...
# 119     80669  Closed fracture of sacrum and coccyx with othe...
# 120     80670  Open fracture of sacrum and coccyx with unspec...
# 121     80679  Open fracture of sacrum and coccyx with other ...
# 122     95200    C1-C4 level with unspecified spinal cord injury
# 123     95201    C1-C4 level with complete lesion of spinal cord
# 124     95204  C1-C4 level with other specified spinal cord i...
# 125     95205    C5-C7 level with unspecified spinal cord injury
# 126     95206    C5-C7 level with complete lesion of spinal cord
# 127     95209  C5-C7 level with other specified spinal cord i...
# 128     95210    T1-T6 level with unspecified spinal cord injury
# 129     95211    T1-T6 level with complete lesion of spinal cord
# 130     95214  T1-T6 level with other specified spinal cord i...
# 131     95215   T7-T12 level with unspecified spinal cord injury
# 132     95216   T7-T12 level with complete lesion of spinal cord
# 133     95219  T7-T12 level with other specified spinal cord ...
# 134     A1781               Tuberculoma of brain and spinal cord
# 135     A1801                              Tuberculosis of spine
# 136     A5212                       Other cerebrospinal syphilis
# 137      C412             Malignant neoplasm of vertebral column
# 138      C701              Malignant neoplasm of spinal meninges
# 139       C72  Malignant neoplasm of spinal cord, cranial ner...
# 140      C720                  Malignant neoplasm of spinal cord
# 141      D166                Benign neoplasm of vertebral column
# 142      D321                 Benign neoplasm of spinal meninges
# 143      D334                     Benign neoplasm of spinal cord
# 144      D421  Neoplasm of uncertain behavior of spinal meninges
# 145      D434      Neoplasm of uncertain behavior of spinal cord
# 146     E9387  Spinal anesthetics causing adverse effects in ...
# 147       G06  Intracranial and intraspinal abscess and granu...
# 148      G061                  Intraspinal abscess and granuloma
# 149       G07  Intracranial and intraspinal abscess and granu...
# 150       G08  Intracranial and intraspinal phlebitis and thr...
# 151       G12      Spinal muscular atrophy and related syndromes
# 152      G120  Infantile spinal muscular atrophy, type I [Wer...
# 153      G121            Other inherited spinal muscular atrophy
# 154     G1225                  Progressive spinal muscle atrophy
# 155      G128  Other spinal muscular atrophies and related sy...
# 156      G129               Spinal muscular atrophy, unspecified
# 157      G320  Subacute combined degeneration of spinal cord ...
# 158       G95      Other and unspecified diseases of spinal cord
# 159     G9511  Acute infarction of spinal cord (embolic) (non...
# 160      G958            Other specified diseases of spinal cord
# 161     G9589            Other specified diseases of spinal cord
# 162      G959                Disease of spinal cord, unspecified
# 163      G960                           Cerebrospinal fluid leak
# 164     G9612            Meningeal adhesions (cerebral) (spinal)
# 165      G970      Cerebrospinal fluid leak from spinal puncture
# 166      G971       Other reaction to spinal and lumbar puncture
# 167      I605  Nontraumatic subarachnoid hemorrhage from vert...
# 168     I6050  Nontraumatic subarachnoid hemorrhage from unsp...
# 169     I6051  Nontraumatic subarachnoid hemorrhage from righ...
# 170     I6052  Nontraumatic subarachnoid hemorrhage from left...
# 171     I6301  Cerebral infarction due to thrombosis of verte...
# 172    I63011  Cerebral infarction due to thrombosis of right...
# 173    I63012  Cerebral infarction due to thrombosis of left ...
# 174    I63013  Cerebral infarction due to thrombosis of bilat...
# 175    I63019  Cerebral infarction due to thrombosis of unspe...
# 176     I6311  Cerebral infarction due to embolism of vertebr...
# 177    I63111  Cerebral infarction due to embolism of right v...
# 178    I63112  Cerebral infarction due to embolism of left ve...
# 179    I63113  Cerebral infarction due to embolism of bilater...
# 180    I63119  Cerebral infarction due to embolism of unspeci...
# 181     I6321  Cerebral infarction due to unspecified occlusi...
# 182    I63211  Cerebral infarction due to unspecified occlusi...
# 183    I63212  Cerebral infarction due to unspecified occlusi...
# 184    I63213  Cerebral infarction due to unspecified occlusi...
# 185    I63219  Cerebral infarction due to unspecified occlusi...
# 186      I650         Occlusion and stenosis of vertebral artery
# 187     I6501   Occlusion and stenosis of right vertebral artery
# 188     I6502    Occlusion and stenosis of left vertebral artery
# 189     I6503  Occlusion and stenosis of bilateral vertebral ...
# 190     I6509  Occlusion and stenosis of unspecified vertebra...
# 191      I726                       Aneurysm of vertebral artery
# 192     I7774                     Dissection of vertebral artery
# 193       M42                             Spinal osteochondrosis
# 194      M420                  Juvenile osteochondrosis of spine
# 195     M4200  Juvenile osteochondrosis of spine, site unspec...
# 196     M4201  Juvenile osteochondrosis of spine, occipito-at...
# 197     M4202  Juvenile osteochondrosis of spine, cervical re...
# 198     M4203  Juvenile osteochondrosis of spine, cervicothor...
# 199     M4204  Juvenile osteochondrosis of spine, thoracic re...
# 200     M4205  Juvenile osteochondrosis of spine, thoracolumb...
# 201     M4206   Juvenile osteochondrosis of spine, lumbar region
# 202     M4207  Juvenile osteochondrosis of spine, lumbosacral...
# 203     M4208  Juvenile osteochondrosis of spine, sacral and ...
# 204     M4209  Juvenile osteochondrosis of spine, multiple si...
# 205      M421                     Adult osteochondrosis of spine
# 206     M4210   Adult osteochondrosis of spine, site unspecified
# 207     M4211  Adult osteochondrosis of spine, occipito-atlan...
# 208     M4212    Adult osteochondrosis of spine, cervical region
# 209     M4213  Adult osteochondrosis of spine, cervicothoraci...
# 210     M4214    Adult osteochondrosis of spine, thoracic region
# 211     M4215  Adult osteochondrosis of spine, thoracolumbar ...
# 212     M4216      Adult osteochondrosis of spine, lumbar region
# 213     M4217  Adult osteochondrosis of spine, lumbosacral re...
# 214     M4218  Adult osteochondrosis of spine, sacral and sac...
# 215     M4219  Adult osteochondrosis of spine, multiple sites...
# 216      M429                Spinal osteochondrosis, unspecified
# 217     M4309             Spondylolysis, multiple sites in spine
# 218     M4319         Spondylolisthesis, multiple sites in spine
# 219      M432                                    Fusion of spine
# 220     M4320                  Fusion of spine, site unspecified
# 221     M4321     Fusion of spine, occipito-atlanto-axial region
# 222     M4322                   Fusion of spine, cervical region
# 223     M4323            Fusion of spine, cervicothoracic region
# 224     M4324                   Fusion of spine, thoracic region
# 225     M4325              Fusion of spine, thoracolumbar region
# 226     M4326                     Fusion of spine, lumbar region
# 227     M4327                Fusion of spine, lumbosacral region
# 228     M4328  Fusion of spine, sacral and sacrococcygeal region
# 229      M435              Other recurrent vertebral dislocation
# 230     M435X              Other recurrent vertebral dislocation
# 231    M435X2  Other recurrent vertebral dislocation, cervica...
# 232    M435X3  Other recurrent vertebral dislocation, cervico...
# 233    M435X4  Other recurrent vertebral dislocation, thoraci...
# 234    M435X5  Other recurrent vertebral dislocation, thoraco...
# 235    M435X6  Other recurrent vertebral dislocation, lumbar ...
# 236    M435X7  Other recurrent vertebral dislocation, lumbosa...
# 237    M435X8  Other recurrent vertebral dislocation, sacral ...
# 238    M435X9  Other recurrent vertebral dislocation, site un...
# 239      M450  Ankylosing spondylitis of multiple sites in spine
# 240      M459  Ankylosing spondylitis of unspecified sites in...
# 241      M460                                Spinal enthesopathy
# 242     M4600              Spinal enthesopathy, site unspecified
# 243     M4601  Spinal enthesopathy, occipito-atlanto-axial re...
# 244     M4602               Spinal enthesopathy, cervical region
# 245     M4603        Spinal enthesopathy, cervicothoracic region
# 246     M4604               Spinal enthesopathy, thoracic region
# 247     M4605          Spinal enthesopathy, thoracolumbar region
# 248     M4606                 Spinal enthesopathy, lumbar region
# 249     M4607            Spinal enthesopathy, lumbosacral region
# 250     M4608  Spinal enthesopathy, sacral and sacrococcygeal...
# 251     M4609       Spinal enthesopathy, multiple sites in spine
# 252      M463        Infection of intervertebral disc (pyogenic)
# 253     M4630  Infection of intervertebral disc (pyogenic), s...
# 254     M4631  Infection of intervertebral disc (pyogenic), o...
# 255     M4632  Infection of intervertebral disc (pyogenic), c...
# 256     M4633  Infection of intervertebral disc (pyogenic), c...
# 257     M4634  Infection of intervertebral disc (pyogenic), t...
# 258     M4635  Infection of intervertebral disc (pyogenic), t...
# 259     M4636  Infection of intervertebral disc (pyogenic), l...
# 260     M4637  Infection of intervertebral disc (pyogenic), l...
# 261     M4638  Infection of intervertebral disc (pyogenic), s...
# 262     M4639  Infection of intervertebral disc (pyogenic), m...
# 263     M4649     Discitis, unspecified, multiple sites in spine
# 264     M4659  Other infective spondylopathies, multiple site...
# 265     M4689  Other specified inflammatory spondylopathies, ...
# 266     M4699  Unspecified inflammatory spondylopathy, multip...
# 267      M470  Anterior spinal and vertebral artery compressi...
# 268     M4701       Anterior spinal artery compression syndromes
# 269    M47011  Anterior spinal artery compression syndromes, ...
# 270    M47012  Anterior spinal artery compression syndromes, ...
# 271    M47013  Anterior spinal artery compression syndromes, ...
# 272    M47014  Anterior spinal artery compression syndromes, ...
# 273    M47015  Anterior spinal artery compression syndromes, ...
# 274    M47016  Anterior spinal artery compression syndromes, ...
# 275    M47019  Anterior spinal artery compression syndromes, ...
# 276     M4702             Vertebral artery compression syndromes
# 277    M47021  Vertebral artery compression syndromes, occipi...
# 278    M47022  Vertebral artery compression syndromes, cervic...
# 279    M47029  Vertebral artery compression syndromes, site u...
# 280      M480                                    Spinal stenosis
# 281     M4800                  Spinal stenosis, site unspecified
# 282     M4801     Spinal stenosis, occipito-atlanto-axial region
# 283     M4802                   Spinal stenosis, cervical region
# 284     M4803            Spinal stenosis, cervicothoracic region
# 285     M4804                   Spinal stenosis, thoracic region
# 286     M4805              Spinal stenosis, thoracolumbar region
# 287     M4806                     Spinal stenosis, lumbar region
# 288    M48061  Spinal stenosis, lumbar region without neuroge...
# 289    M48062  Spinal stenosis, lumbar region with neurogenic...
# 290     M4807                Spinal stenosis, lumbosacral region
# 291     M4808  Spinal stenosis, sacral and sacrococcygeal region
# 292     M4819  Ankylosing hyperostosis [Forestier], multiple ...
# 293      M482                                      Kissing spine
# 294     M4820                    Kissing spine, site unspecified
# 295     M4821       Kissing spine, occipito-atlanto-axial region
# 296     M4822                     Kissing spine, cervical region
# 297     M4823              Kissing spine, cervicothoracic region
# 298     M4824                     Kissing spine, thoracic region
# 299     M4825                Kissing spine, thoracolumbar region
# 300     M4826                       Kissing spine, lumbar region
# 301     M4827                  Kissing spine, lumbosacral region
# 302     M4989  Spondylopathy in diseases classified elsewhere...
# 303       M51  Thoracic, thoracolumbar, and lumbosacral inter...
# 304      M510  Thoracic, thoracolumbar and lumbosacral interv...
# 305     M5104  Intervertebral disc disorders with myelopathy,...
# 306     M5105  Intervertebral disc disorders with myelopathy,...
# 307     M5106  Intervertebral disc disorders with myelopathy,...
# 308      M511  Thoracic, thoracolumbar and lumbosacral interv...
# 309     M5114  Intervertebral disc disorders with radiculopat...
# 310     M5115  Intervertebral disc disorders with radiculopat...
# 311     M5116  Intervertebral disc disorders with radiculopat...
# 312     M5117  Intervertebral disc disorders with radiculopat...
# 313      M512  Other thoracic, thoracolumbar and lumbosacral ...
# 314     M5124  Other intervertebral disc displacement, thorac...
# 315     M5125  Other intervertebral disc displacement, thorac...
# 316     M5126  Other intervertebral disc displacement, lumbar...
# 317     M5127  Other intervertebral disc displacement, lumbos...
# 318      M513  Other thoracic, thoracolumbar and lumbosacral ...
# 319     M5134  Other intervertebral disc degeneration, thorac...
# 320     M5135  Other intervertebral disc degeneration, thorac...
# 321     M5136  Other intervertebral disc degeneration, lumbar...
# 322     M5137  Other intervertebral disc degeneration, lumbos...
# 323      M518  Other thoracic, thoracolumbar and lumbosacral ...
# 324     M5184  Other intervertebral disc disorders, thoracic ...
# 325     M5185  Other intervertebral disc disorders, thoracolu...
# 326     M5186  Other intervertebral disc disorders, lumbar re...
# 327     M5187  Other intervertebral disc disorders, lumbosacr...
# 328      M519  Unspecified thoracic, thoracolumbar and lumbos...
# 329      M532                               Spinal instabilities
# 330     M532X                               Spinal instabilities
# 331    M532X1  Spinal instabilities, occipito-atlanto-axial r...
# 332    M532X2              Spinal instabilities, cervical region
# 333    M532X3       Spinal instabilities, cervicothoracic region
# 334    M532X4              Spinal instabilities, thoracic region
# 335    M532X5         Spinal instabilities, thoracolumbar region
# 336    M532X6                Spinal instabilities, lumbar region
# 337    M532X7           Spinal instabilities, lumbosacral region
# 338    M532X8  Spinal instabilities, sacral and sacrococcygea...
# 339    M532X9             Spinal instabilities, site unspecified
# 340     M5409  Panniculitis affecting regions, neck and back,...
# 341      M546                             Pain in thoracic spine
# 342      M991                    Subluxation complex (vertebral)
# 343     M9910     Subluxation complex (vertebral) of head region
# 344     M9911  Subluxation complex (vertebral) of cervical re...
# 345     M9912  Subluxation complex (vertebral) of thoracic re...
# 346     M9913   Subluxation complex (vertebral) of lumbar region
# 347     M9914   Subluxation complex (vertebral) of sacral region
# 348     M9915   Subluxation complex (vertebral) of pelvic region
# 349     M9916  Subluxation complex (vertebral) of lower extre...
# 350     M9917  Subluxation complex (vertebral) of upper extre...
# 351     M9918        Subluxation complex (vertebral) of rib cage
# 352     M9919  Subluxation complex (vertebral) of abdomen and...
# 353      M995       Intervertebral disc stenosis of neural canal
# 354     M9950  Intervertebral disc stenosis of neural canal o...
# 355     M9951  Intervertebral disc stenosis of neural canal o...
# 356     M9952  Intervertebral disc stenosis of neural canal o...
# 357     M9953  Intervertebral disc stenosis of neural canal o...
# 358     M9954  Intervertebral disc stenosis of neural canal o...
# 359     M9955  Intervertebral disc stenosis of neural canal o...
# 360     M9956  Intervertebral disc stenosis of neural canal o...
# 361     M9957  Intervertebral disc stenosis of neural canal o...
# 362     M9958  Intervertebral disc stenosis of neural canal o...
# 363     M9959  Intervertebral disc stenosis of neural canal o...
# 364      M996  Osseous and subluxation stenosis of interverte...
# 365     M9960  Osseous and subluxation stenosis of interverte...
# 366     M9961  Osseous and subluxation stenosis of interverte...
# 367     M9962  Osseous and subluxation stenosis of interverte...
# 368     M9963  Osseous and subluxation stenosis of interverte...
# 369     M9964  Osseous and subluxation stenosis of interverte...
# 370     M9965  Osseous and subluxation stenosis of interverte...
# 371     M9966  Osseous and subluxation stenosis of interverte...
# 372     M9967  Osseous and subluxation stenosis of interverte...
# 373     M9968  Osseous and subluxation stenosis of interverte...
# 374     M9969  Osseous and subluxation stenosis of interverte...
# 375      M997  Connective tissue and disc stenosis of interve...
# 376     M9970  Connective tissue and disc stenosis of interve...
# 377     M9971  Connective tissue and disc stenosis of interve...
# 378     M9972  Connective tissue and disc stenosis of interve...
# 379     M9973  Connective tissue and disc stenosis of interve...
# 380     M9974  Connective tissue and disc stenosis of interve...
# 381     M9975  Connective tissue and disc stenosis of interve...
# 382     M9976  Connective tissue and disc stenosis of interve...
# 383     M9977  Connective tissue and disc stenosis of interve...
# 384     M9978  Connective tissue and disc stenosis of interve...
# 385     M9979  Connective tissue and disc stenosis of interve...
# 386      O294  Spinal and epidural anesthesia induced headach...
# 387     O2940  Spinal and epidural anesthesia induced headach...
# 388     O2941  Spinal and epidural anesthesia induced headach...
# 389     O2942  Spinal and epidural anesthesia induced headach...
# 390     O2943  Spinal and epidural anesthesia induced headach...
# 391      O295  Other complications of spinal and epidural ane...
# 392     O295X  Other complications of spinal and epidural ane...
# 393    O295X1  Other complications of spinal and epidural ane...
# 394    O295X2  Other complications of spinal and epidural ane...
# 395    O295X3  Other complications of spinal and epidural ane...
# 396    O295X9  Other complications of spinal and epidural ane...
# 397      O745  Spinal and epidural anesthesia-induced headach...
# 398      O746  Other complications of spinal and epidural ane...
# 399      O894  Spinal and epidural anesthesia-induced headach...
# 400      O895  Other complications of spinal and epidural ane...
# 401      P115              Birth injury to spine and spinal cord
# 402       Q06      Other congenital malformations of spinal cord
# 403      Q061            Hypoplasia and dysplasia of spinal cord
# 404      Q068  Other specified congenital malformations of sp...
# 405      Q069  Congenital malformation of spinal cord, unspec...
# 406       Q67  Congenital musculoskeletal deformities of head...
# 407      Q675                      Congenital deformity of spine
# 408       Q76  Congenital malformations of spine and bony thorax
# 409      Q764  Other congenital malformations of spine, not a...
# 410     Q7649  Other congenital malformations of spine, not a...
# 411       Q77  Osteochondrodysplasia with defects of growth o...
# 412      Q778  Other osteochondrodysplasia with defects of gr...
# 413      Q779  Osteochondrodysplasia with defects of growth o...
# 414       R83           Abnormal findings in cerebrospinal fluid
# 415      R830   Abnormal level of enzymes in cerebrospinal fluid
# 416      R831  Abnormal level of hormones in cerebrospinal fluid
# 417      R832  Abnormal level of other drugs, medicaments and...
# 418      R833  Abnormal level of substances chiefly nonmedici...
# 419      R834  Abnormal immunological findings in cerebrospin...
# 420      R835  Abnormal microbiological findings in cerebrosp...
# 421      R836  Abnormal cytological findings in cerebrospinal...
# 422      R838     Other abnormal findings in cerebrospinal fluid
# 423      R839  Unspecified abnormal finding in cerebrospinal ...
# 424      S130  Traumatic rupture of cervical intervertebral disc
# 425   S130XXA  Traumatic rupture of cervical intervertebral d...
# 426   S130XXD  Traumatic rupture of cervical intervertebral d...
# 427   S130XXS  Traumatic rupture of cervical intervertebral d...
# 428      S134              Sprain of ligaments of cervical spine
# 429   S134XXA  Sprain of ligaments of cervical spine, initial...
# 430   S134XXD  Sprain of ligaments of cervical spine, subsequ...
# 431   S134XXS     Sprain of ligaments of cervical spine, sequela
# 432       S14     Injury of nerves and spinal cord at neck level
# 433      S140       Concussion and edema of cervical spinal cord
# 434   S140XXA  Concussion and edema of cervical spinal cord, ...
# 435   S140XXD  Concussion and edema of cervical spinal cord, ...
# 436   S140XXS  Concussion and edema of cervical spinal cord, ...
# 437      S141  Other and unspecified injuries of cervical spi...
# 438     S1410         Unspecified injury of cervical spinal cord
# 439    S14101  Unspecified injury at C1 level of cervical spi...
# 440   S14101A  Unspecified injury at C1 level of cervical spi...
# 441   S14101D  Unspecified injury at C1 level of cervical spi...
# 442   S14101S  Unspecified injury at C1 level of cervical spi...
# 443    S14102  Unspecified injury at C2 level of cervical spi...
# 444   S14102A  Unspecified injury at C2 level of cervical spi...
# 445   S14102D  Unspecified injury at C2 level of cervical spi...
# 446   S14102S  Unspecified injury at C2 level of cervical spi...
# 447    S14103  Unspecified injury at C3 level of cervical spi...
# 448   S14103A  Unspecified injury at C3 level of cervical spi...
# 449   S14103D  Unspecified injury at C3 level of cervical spi...
# 450   S14103S  Unspecified injury at C3 level of cervical spi...
# 451    S14104  Unspecified injury at C4 level of cervical spi...
# 452   S14104A  Unspecified injury at C4 level of cervical spi...
# 453   S14104D  Unspecified injury at C4 level of cervical spi...
# 454   S14104S  Unspecified injury at C4 level of cervical spi...
# 455    S14105  Unspecified injury at C5 level of cervical spi...
# 456   S14105A  Unspecified injury at C5 level of cervical spi...
# 457   S14105D  Unspecified injury at C5 level of cervical spi...
# 458   S14105S  Unspecified injury at C5 level of cervical spi...
# 459    S14106  Unspecified injury at C6 level of cervical spi...
# 460   S14106A  Unspecified injury at C6 level of cervical spi...
# 461   S14106D  Unspecified injury at C6 level of cervical spi...
# 462   S14106S  Unspecified injury at C6 level of cervical spi...
# 463    S14107  Unspecified injury at C7 level of cervical spi...
# 464   S14107A  Unspecified injury at C7 level of cervical spi...
# 465   S14107D  Unspecified injury at C7 level of cervical spi...
# 466   S14107S  Unspecified injury at C7 level of cervical spi...
# 467    S14108  Unspecified injury at C8 level of cervical spi...
# 468   S14108A  Unspecified injury at C8 level of cervical spi...
# 469   S14108D  Unspecified injury at C8 level of cervical spi...
# 470   S14108S  Unspecified injury at C8 level of cervical spi...
# 471    S14109  Unspecified injury at unspecified level of cer...
# 472   S14109A  Unspecified injury at unspecified level of cer...
# 473   S14109D  Unspecified injury at unspecified level of cer...
# 474   S14109S  Unspecified injury at unspecified level of cer...
# 475     S1411            Complete lesion of cervical spinal cord
# 476    S14111  Complete lesion at C1 level of cervical spinal...
# 477   S14111A  Complete lesion at C1 level of cervical spinal...
# 478   S14111D  Complete lesion at C1 level of cervical spinal...
# 479   S14111S  Complete lesion at C1 level of cervical spinal...
# 480    S14112  Complete lesion at C2 level of cervical spinal...
# 481   S14112A  Complete lesion at C2 level of cervical spinal...
# 482   S14112D  Complete lesion at C2 level of cervical spinal...
# 483   S14112S  Complete lesion at C2 level of cervical spinal...
# 484    S14113  Complete lesion at C3 level of cervical spinal...
# 485   S14113A  Complete lesion at C3 level of cervical spinal...
# 486   S14113D  Complete lesion at C3 level of cervical spinal...
# 487   S14113S  Complete lesion at C3 level of cervical spinal...
# 488    S14114  Complete lesion at C4 level of cervical spinal...
# 489   S14114A  Complete lesion at C4 level of cervical spinal...
# 490   S14114D  Complete lesion at C4 level of cervical spinal...
# 491   S14114S  Complete lesion at C4 level of cervical spinal...
# 492    S14115  Complete lesion at C5 level of cervical spinal...
# 493   S14115A  Complete lesion at C5 level of cervical spinal...
# 494   S14115D  Complete lesion at C5 level of cervical spinal...
# 495   S14115S  Complete lesion at C5 level of cervical spinal...
# 496    S14116  Complete lesion at C6 level of cervical spinal...
# 497   S14116A  Complete lesion at C6 level of cervical spinal...
# 498   S14116D  Complete lesion at C6 level of cervical spinal...
# 499   S14116S  Complete lesion at C6 level of cervical spinal...
# 500    S14117  Complete lesion at C7 level of cervical spinal...
# 501   S14117A  Complete lesion at C7 level of cervical spinal...
# 502   S14117D  Complete lesion at C7 level of cervical spinal...
# 503   S14117S  Complete lesion at C7 level of cervical spinal...
# 504    S14118  Complete lesion at C8 level of cervical spinal...
# 505   S14118A  Complete lesion at C8 level of cervical spinal...
# 506   S14118D  Complete lesion at C8 level of cervical spinal...
# 507   S14118S  Complete lesion at C8 level of cervical spinal...
# 508    S14119  Complete lesion at unspecified level of cervic...
# 509   S14119A  Complete lesion at unspecified level of cervic...
# 510   S14119D  Complete lesion at unspecified level of cervic...
# 511   S14119S  Complete lesion at unspecified level of cervic...
# 512     S1412      Central cord syndrome of cervical spinal cord
# 513    S14121  Central cord syndrome at C1 level of cervical ...
# 514   S14121A  Central cord syndrome at C1 level of cervical ...
# 515   S14121D  Central cord syndrome at C1 level of cervical ...
# 516   S14121S  Central cord syndrome at C1 level of cervical ...
# 517    S14122  Central cord syndrome at C2 level of cervical ...
# 518   S14122A  Central cord syndrome at C2 level of cervical ...
# 519   S14122D  Central cord syndrome at C2 level of cervical ...
# 520   S14122S  Central cord syndrome at C2 level of cervical ...
# 521    S14123  Central cord syndrome at C3 level of cervical ...
# 522   S14123A  Central cord syndrome at C3 level of cervical ...
# 523   S14123D  Central cord syndrome at C3 level of cervical ...
# 524   S14123S  Central cord syndrome at C3 level of cervical ...
# 525    S14124  Central cord syndrome at C4 level of cervical ...
# 526   S14124A  Central cord syndrome at C4 level of cervical ...
# 527   S14124D  Central cord syndrome at C4 level of cervical ...
# 528   S14124S  Central cord syndrome at C4 level of cervical ...
# 529    S14125  Central cord syndrome at C5 level of cervical ...
# 530   S14125A  Central cord syndrome at C5 level of cervical ...
# 531   S14125D  Central cord syndrome at C5 level of cervical ...
# 532   S14125S  Central cord syndrome at C5 level of cervical ...
# 533    S14126  Central cord syndrome at C6 level of cervical ...
# 534   S14126A  Central cord syndrome at C6 level of cervical ...
# 535   S14126D  Central cord syndrome at C6 level of cervical ...
# 536   S14126S  Central cord syndrome at C6 level of cervical ...
# 537    S14127  Central cord syndrome at C7 level of cervical ...
# 538   S14127A  Central cord syndrome at C7 level of cervical ...
# 539   S14127D  Central cord syndrome at C7 level of cervical ...
# 540   S14127S  Central cord syndrome at C7 level of cervical ...
# 541    S14128  Central cord syndrome at C8 level of cervical ...
# 542   S14128A  Central cord syndrome at C8 level of cervical ...
# 543   S14128D  Central cord syndrome at C8 level of cervical ...
# 544   S14128S  Central cord syndrome at C8 level of cervical ...
# 545    S14129  Central cord syndrome at unspecified level of ...
# 546   S14129A  Central cord syndrome at unspecified level of ...
# 547   S14129D  Central cord syndrome at unspecified level of ...
# 548   S14129S  Central cord syndrome at unspecified level of ...
# 549     S1413     Anterior cord syndrome of cervical spinal cord
# 550    S14131  Anterior cord syndrome at C1 level of cervical...
# 551   S14131A  Anterior cord syndrome at C1 level of cervical...
# 552   S14131D  Anterior cord syndrome at C1 level of cervical...
# 553   S14131S  Anterior cord syndrome at C1 level of cervical...
# 554    S14132  Anterior cord syndrome at C2 level of cervical...
# 555   S14132A  Anterior cord syndrome at C2 level of cervical...
# 556   S14132D  Anterior cord syndrome at C2 level of cervical...
# 557   S14132S  Anterior cord syndrome at C2 level of cervical...
# 558    S14133  Anterior cord syndrome at C3 level of cervical...
# 559   S14133A  Anterior cord syndrome at C3 level of cervical...
# 560   S14133D  Anterior cord syndrome at C3 level of cervical...
# 561   S14133S  Anterior cord syndrome at C3 level of cervical...
# 562    S14134  Anterior cord syndrome at C4 level of cervical...
# 563   S14134A  Anterior cord syndrome at C4 level of cervical...
# 564   S14134D  Anterior cord syndrome at C4 level of cervical...
# 565   S14134S  Anterior cord syndrome at C4 level of cervical...
# 566    S14135  Anterior cord syndrome at C5 level of cervical...
# 567   S14135A  Anterior cord syndrome at C5 level of cervical...
# 568   S14135D  Anterior cord syndrome at C5 level of cervical...
# 569   S14135S  Anterior cord syndrome at C5 level of cervical...
# 570    S14136  Anterior cord syndrome at C6 level of cervical...
# 571   S14136A  Anterior cord syndrome at C6 level of cervical...
# 572   S14136D  Anterior cord syndrome at C6 level of cervical...
# 573   S14136S  Anterior cord syndrome at C6 level of cervical...
# 574    S14137  Anterior cord syndrome at C7 level of cervical...
# 575   S14137A  Anterior cord syndrome at C7 level of cervical...
# 576   S14137D  Anterior cord syndrome at C7 level of cervical...
# 577   S14137S  Anterior cord syndrome at C7 level of cervical...
# 578    S14138  Anterior cord syndrome at C8 level of cervical...
# 579   S14138A  Anterior cord syndrome at C8 level of cervical...
# 580   S14138D  Anterior cord syndrome at C8 level of cervical...
# 581   S14138S  Anterior cord syndrome at C8 level of cervical...
# 582    S14139  Anterior cord syndrome at unspecified level of...
# 583   S14139A  Anterior cord syndrome at unspecified level of...
# 584   S14139D  Anterior cord syndrome at unspecified level of...
# 585   S14139S  Anterior cord syndrome at unspecified level of...
# 586     S1414     Brown-Sequard syndrome of cervical spinal cord
# 587    S14141  Brown-Sequard syndrome at C1 level of cervical...
# 588   S14141A  Brown-Sequard syndrome at C1 level of cervical...
# 589   S14141D  Brown-Sequard syndrome at C1 level of cervical...
# 590   S14141S  Brown-Sequard syndrome at C1 level of cervical...
# 591    S14142  Brown-Sequard syndrome at C2 level of cervical...
# 592   S14142A  Brown-Sequard syndrome at C2 level of cervical...
# 593   S14142D  Brown-Sequard syndrome at C2 level of cervical...
# 594   S14142S  Brown-Sequard syndrome at C2 level of cervical...
# 595    S14143  Brown-Sequard syndrome at C3 level of cervical...
# 596   S14143A  Brown-Sequard syndrome at C3 level of cervical...
# 597   S14143D  Brown-Sequard syndrome at C3 level of cervical...
# 598   S14143S  Brown-Sequard syndrome at C3 level of cervical...
# 599    S14144  Brown-Sequard syndrome at C4 level of cervical...
# 600   S14144A  Brown-Sequard syndrome at C4 level of cervical...
# 601   S14144D  Brown-Sequard syndrome at C4 level of cervical...
# 602   S14144S  Brown-Sequard syndrome at C4 level of cervical...
# 603    S14145  Brown-Sequard syndrome at C5 level of cervical...
# 604   S14145A  Brown-Sequard syndrome at C5 level of cervical...
# 605   S14145D  Brown-Sequard syndrome at C5 level of cervical...
# 606   S14145S  Brown-Sequard syndrome at C5 level of cervical...
# 607    S14146  Brown-Sequard syndrome at C6 level of cervical...
# 608   S14146A  Brown-Sequard syndrome at C6 level of cervical...
# 609   S14146D  Brown-Sequard syndrome at C6 level of cervical...
# 610   S14146S  Brown-Sequard syndrome at C6 level of cervical...
# 611    S14147  Brown-Sequard syndrome at C7 level of cervical...
# 612   S14147A  Brown-Sequard syndrome at C7 level of cervical...
# 613   S14147D  Brown-Sequard syndrome at C7 level of cervical...
# 614   S14147S  Brown-Sequard syndrome at C7 level of cervical...
# 615    S14148  Brown-Sequard syndrome at C8 level of cervical...
# 616   S14148A  Brown-Sequard syndrome at C8 level of cervical...
# 617   S14148D  Brown-Sequard syndrome at C8 level of cervical...
# 618   S14148S  Brown-Sequard syndrome at C8 level of cervical...
# 619    S14149  Brown-Sequard syndrome at unspecified level of...
# 620   S14149A  Brown-Sequard syndrome at unspecified level of...
# 621   S14149D  Brown-Sequard syndrome at unspecified level of...
# 622   S14149S  Brown-Sequard syndrome at unspecified level of...
# 623     S1415   Other incomplete lesions of cervical spinal cord
# 624    S14151  Other incomplete lesion at C1 level of cervica...
# 625   S14151A  Other incomplete lesion at C1 level of cervica...
# 626   S14151D  Other incomplete lesion at C1 level of cervica...
# 627   S14151S  Other incomplete lesion at C1 level of cervica...
# 628    S14152  Other incomplete lesion at C2 level of cervica...
# 629   S14152A  Other incomplete lesion at C2 level of cervica...
# 630   S14152D  Other incomplete lesion at C2 level of cervica...
# 631   S14152S  Other incomplete lesion at C2 level of cervica...
# 632    S14153  Other incomplete lesion at C3 level of cervica...
# 633   S14153A  Other incomplete lesion at C3 level of cervica...
# 634   S14153D  Other incomplete lesion at C3 level of cervica...
# 635   S14153S  Other incomplete lesion at C3 level of cervica...
# 636    S14154  Other incomplete lesion at C4 level of cervica...
# 637   S14154A  Other incomplete lesion at C4 level of cervica...
# 638   S14154D  Other incomplete lesion at C4 level of cervica...
# 639   S14154S  Other incomplete lesion at C4 level of cervica...
# 640    S14155  Other incomplete lesion at C5 level of cervica...
# 641   S14155A  Other incomplete lesion at C5 level of cervica...
# 642   S14155D  Other incomplete lesion at C5 level of cervica...
# 643   S14155S  Other incomplete lesion at C5 level of cervica...
# 644    S14156  Other incomplete lesion at C6 level of cervica...
# 645   S14156A  Other incomplete lesion at C6 level of cervica...
# 646   S14156D  Other incomplete lesion at C6 level of cervica...
# 647   S14156S  Other incomplete lesion at C6 level of cervica...
# 648    S14157  Other incomplete lesion at C7 level of cervica...
# 649   S14157A  Other incomplete lesion at C7 level of cervica...
# 650   S14157D  Other incomplete lesion at C7 level of cervica...
# 651   S14157S  Other incomplete lesion at C7 level of cervica...
# 652    S14158  Other incomplete lesion at C8 level of cervica...
# 653   S14158A  Other incomplete lesion at C8 level of cervica...
# 654   S14158D  Other incomplete lesion at C8 level of cervica...
# 655   S14158S  Other incomplete lesion at C8 level of cervica...
# 656    S14159  Other incomplete lesion at unspecified level o...
# 657   S14159A  Other incomplete lesion at unspecified level o...
# 658   S14159D  Other incomplete lesion at unspecified level o...
# 659   S14159S  Other incomplete lesion at unspecified level o...
# 660      S142             Injury of nerve root of cervical spine
# 661   S142XXA  Injury of nerve root of cervical spine, initia...
# 662   S142XXD  Injury of nerve root of cervical spine, subseq...
# 663   S142XXS    Injury of nerve root of cervical spine, sequela
# 664      S151                         Injury of vertebral artery
# 665     S1510             Unspecified injury of vertebral artery
# 666    S15101       Unspecified injury of right vertebral artery
# 667   S15101A  Unspecified injury of right vertebral artery, ...
# 668   S15101D  Unspecified injury of right vertebral artery, ...
# 669   S15101S  Unspecified injury of right vertebral artery, ...
# 670    S15102        Unspecified injury of left vertebral artery
# 671   S15102A  Unspecified injury of left vertebral artery, i...
# 672   S15102D  Unspecified injury of left vertebral artery, s...
# 673   S15102S  Unspecified injury of left vertebral artery, s...
# 674    S15109  Unspecified injury of unspecified vertebral ar...
# 675   S15109A  Unspecified injury of unspecified vertebral ar...
# 676   S15109D  Unspecified injury of unspecified vertebral ar...
# 677   S15109S  Unspecified injury of unspecified vertebral ar...
# 678     S1511               Minor laceration of vertebral artery
# 679    S15111         Minor laceration of right vertebral artery
# 680   S15111A  Minor laceration of right vertebral artery, in...
# 681   S15111D  Minor laceration of right vertebral artery, su...
# 682   S15111S  Minor laceration of right vertebral artery, se...
# 683    S15112          Minor laceration of left vertebral artery
# 684   S15112A  Minor laceration of left vertebral artery, ini...
# 685   S15112D  Minor laceration of left vertebral artery, sub...
# 686   S15112S  Minor laceration of left vertebral artery, seq...
# 687    S15119   Minor laceration of unspecified vertebral artery
# 688   S15119A  Minor laceration of unspecified vertebral arte...
# 689   S15119D  Minor laceration of unspecified vertebral arte...
# 690   S15119S  Minor laceration of unspecified vertebral arte...
# 691     S1512               Major laceration of vertebral artery
# 692    S15121         Major laceration of right vertebral artery
# 693   S15121A  Major laceration of right vertebral artery, in...
# 694   S15121D  Major laceration of right vertebral artery, su...
# 695   S15121S  Major laceration of right vertebral artery, se...
# 696    S15122          Major laceration of left vertebral artery
# 697   S15122A  Major laceration of left vertebral artery, ini...
# 698   S15122D  Major laceration of left vertebral artery, sub...
# 699   S15122S  Major laceration of left vertebral artery, seq...
# 700    S15129   Major laceration of unspecified vertebral artery
# 701   S15129A  Major laceration of unspecified vertebral arte...
# 702   S15129D  Major laceration of unspecified vertebral arte...
# 703   S15129S  Major laceration of unspecified vertebral arte...
# 704     S1519         Other specified injury of vertebral artery
# 705    S15191   Other specified injury of right vertebral artery
# 706   S15191A  Other specified injury of right vertebral arte...
# ...
# 890   S34101S  Unspecified injury to L1 level of lumbar spina...
# 891    S34102  Unspecified injury to L2 level of lumbar spina...
# 892   S34102A  Unspecified injury to L2 level of lumbar spina...
# 893   S34102D  Unspecified injury to L2 level of lumbar spina...
# 894   S34102S  Unspecified injury to L2 level of lumbar spina...
# 895    S34103  Unspecified injury to L3 level of lumbar spina...
# 896   S34103A  Unspecified injury to L3 level of lumbar spina...
# 897   S34103D  Unspecified injury to L3 level of lumbar spina...
# 898   S34103S  Unspecified injury to L3 level of lumbar spina...
# 899    S34104  Unspecified injury to L4 level of lumbar spina...
# 900   S34104A  Unspecified injury to L4 level of lumbar spina...
# 901   S34104D  Unspecified injury to L4 level of lumbar spina...
# 902   S34104S  Unspecified injury to L4 level of lumbar spina...
# 903    S34105  Unspecified injury to L5 level of lumbar spina...
# 904   S34105A  Unspecified injury to L5 level of lumbar spina...
# 905   S34105D  Unspecified injury to L5 level of lumbar spina...
# 906   S34105S  Unspecified injury to L5 level of lumbar spina...
# 907    S34109  Unspecified injury to unspecified level of lum...
# 908   S34109A  Unspecified injury to unspecified level of lum...
# 909   S34109D  Unspecified injury to unspecified level of lum...
# 910   S34109S  Unspecified injury to unspecified level of lum...
# 911     S3411              Complete lesion of lumbar spinal cord
# 912    S34111  Complete lesion of L1 level of lumbar spinal cord
# 913   S34111A  Complete lesion of L1 level of lumbar spinal c...
# 914   S34111D  Complete lesion of L1 level of lumbar spinal c...
# 915   S34111S  Complete lesion of L1 level of lumbar spinal c...
# 916    S34112  Complete lesion of L2 level of lumbar spinal cord
# 917   S34112A  Complete lesion of L2 level of lumbar spinal c...
# 918   S34112D  Complete lesion of L2 level of lumbar spinal c...
# 919   S34112S  Complete lesion of L2 level of lumbar spinal c...
# 920    S34113  Complete lesion of L3 level of lumbar spinal cord
# 921   S34113A  Complete lesion of L3 level of lumbar spinal c...
# 922   S34113D  Complete lesion of L3 level of lumbar spinal c...
# 923   S34113S  Complete lesion of L3 level of lumbar spinal c...
# 924    S34114  Complete lesion of L4 level of lumbar spinal cord
# 925   S34114A  Complete lesion of L4 level of lumbar spinal c...
# 926   S34114D  Complete lesion of L4 level of lumbar spinal c...
# 927   S34114S  Complete lesion of L4 level of lumbar spinal c...
# 928    S34115  Complete lesion of L5 level of lumbar spinal cord
# 929   S34115A  Complete lesion of L5 level of lumbar spinal c...
# 930   S34115D  Complete lesion of L5 level of lumbar spinal c...
# 931   S34115S  Complete lesion of L5 level of lumbar spinal c...
# 932    S34119  Complete lesion of unspecified level of lumbar...
# 933   S34119A  Complete lesion of unspecified level of lumbar...
# 934   S34119D  Complete lesion of unspecified level of lumbar...
# 935   S34119S  Complete lesion of unspecified level of lumbar...
# 936     S3412            Incomplete lesion of lumbar spinal cord
# 937    S34121  Incomplete lesion of L1 level of lumbar spinal...
# 938   S34121A  Incomplete lesion of L1 level of lumbar spinal...
# 939   S34121D  Incomplete lesion of L1 level of lumbar spinal...
# 940   S34121S  Incomplete lesion of L1 level of lumbar spinal...
# 941    S34122  Incomplete lesion of L2 level of lumbar spinal...
# 942   S34122A  Incomplete lesion of L2 level of lumbar spinal...
# 943   S34122D  Incomplete lesion of L2 level of lumbar spinal...
# 944   S34122S  Incomplete lesion of L2 level of lumbar spinal...
# 945    S34123  Incomplete lesion of L3 level of lumbar spinal...
# 946   S34123A  Incomplete lesion of L3 level of lumbar spinal...
# 947   S34123D  Incomplete lesion of L3 level of lumbar spinal...
# 948   S34123S  Incomplete lesion of L3 level of lumbar spinal...
# 949    S34124  Incomplete lesion of L4 level of lumbar spinal...
# 950   S34124A  Incomplete lesion of L4 level of lumbar spinal...
# 951   S34124D  Incomplete lesion of L4 level of lumbar spinal...
# 952   S34124S  Incomplete lesion of L4 level of lumbar spinal...
# 953    S34125  Incomplete lesion of L5 level of lumbar spinal...
# 954   S34125A  Incomplete lesion of L5 level of lumbar spinal...
# 955   S34125D  Incomplete lesion of L5 level of lumbar spinal...
# 956   S34125S  Incomplete lesion of L5 level of lumbar spinal...
# 957    S34129  Incomplete lesion of unspecified level of lumb...
# 958   S34129A  Incomplete lesion of unspecified level of lumb...
# 959   S34129D  Incomplete lesion of unspecified level of lumb...
# 960   S34129S  Incomplete lesion of unspecified level of lumb...
# 961     S3413  Other and unspecified injury to sacral spinal ...
# 962    S34131              Complete lesion of sacral spinal cord
# 963   S34131A  Complete lesion of sacral spinal cord, initial...
# 964   S34131D  Complete lesion of sacral spinal cord, subsequ...
# 965   S34131S     Complete lesion of sacral spinal cord, sequela
# 966    S34132            Incomplete lesion of sacral spinal cord
# 967   S34132A  Incomplete lesion of sacral spinal cord, initi...
# 968   S34132D  Incomplete lesion of sacral spinal cord, subse...
# 969   S34132S   Incomplete lesion of sacral spinal cord, sequela
# 970    S34139           Unspecified injury to sacral spinal cord
# 971   S34139A  Unspecified injury to sacral spinal cord, init...
# 972   S34139D  Unspecified injury to sacral spinal cord, subs...
# 973   S34139S  Unspecified injury to sacral spinal cord, sequela
# 974      S342    Injury of nerve root of lumbar and sacral spine
# 975     S3421               Injury of nerve root of lumbar spine
# 976   S3421XA  Injury of nerve root of lumbar spine, initial ...
# 977   S3421XD  Injury of nerve root of lumbar spine, subseque...
# 978   S3421XS      Injury of nerve root of lumbar spine, sequela
# 979     S3422               Injury of nerve root of sacral spine
# 980   S3422XA  Injury of nerve root of sacral spine, initial ...
# 981   S3422XD  Injury of nerve root of sacral spine, subseque...
# 982   S3422XS      Injury of nerve root of sacral spine, sequela
# 983     S8211                           Fracture of tibial spine
# 984    S82111           Displaced fracture of right tibial spine
# 985   S82111A  Displaced fracture of right tibial spine, init...
# 986   S82111B  Displaced fracture of right tibial spine, init...
# 987   S82111C  Displaced fracture of right tibial spine, init...
# 988   S82111D  Displaced fracture of right tibial spine, subs...
# 989   S82111E  Displaced fracture of right tibial spine, subs...
# 990   S82111F  Displaced fracture of right tibial spine, subs...
# 991   S82111G  Displaced fracture of right tibial spine, subs...
# 992   S82111H  Displaced fracture of right tibial spine, subs...
# 993   S82111J  Displaced fracture of right tibial spine, subs...
# 994   S82111K  Displaced fracture of right tibial spine, subs...
# 995   S82111M  Displaced fracture of right tibial spine, subs...
# 996   S82111N  Displaced fracture of right tibial spine, subs...
# 997   S82111P  Displaced fracture of right tibial spine, subs...
# 998   S82111Q  Displaced fracture of right tibial spine, subs...
# 999   S82111R  Displaced fracture of right tibial spine, subs...
# 1000  S82111S  Displaced fracture of right tibial spine, sequela
# 1001   S82112            Displaced fracture of left tibial spine
# 1002  S82112A  Displaced fracture of left tibial spine, initi...
# 1003  S82112B  Displaced fracture of left tibial spine, initi...
# 1004  S82112C  Displaced fracture of left tibial spine, initi...
# 1005  S82112D  Displaced fracture of left tibial spine, subse...
# 1006  S82112E  Displaced fracture of left tibial spine, subse...
# 1007  S82112F  Displaced fracture of left tibial spine, subse...
# 1008  S82112G  Displaced fracture of left tibial spine, subse...
# 1009  S82112H  Displaced fracture of left tibial spine, subse...
# 1010  S82112J  Displaced fracture of left tibial spine, subse...
# 1011  S82112K  Displaced fracture of left tibial spine, subse...
# 1012  S82112M  Displaced fracture of left tibial spine, subse...
# 1013  S82112N  Displaced fracture of left tibial spine, subse...
# 1014  S82112P  Displaced fracture of left tibial spine, subse...
# 1015  S82112Q  Displaced fracture of left tibial spine, subse...
# 1016  S82112R  Displaced fracture of left tibial spine, subse...
# 1017  S82112S   Displaced fracture of left tibial spine, sequela
# 1018   S82113     Displaced fracture of unspecified tibial spine
# 1019  S82113A  Displaced fracture of unspecified tibial spine...
# 1020  S82113B  Displaced fracture of unspecified tibial spine...
# 1021  S82113C  Displaced fracture of unspecified tibial spine...
# 1022  S82113D  Displaced fracture of unspecified tibial spine...
# 1023  S82113E  Displaced fracture of unspecified tibial spine...
# 1024  S82113F  Displaced fracture of unspecified tibial spine...
# 1025  S82113G  Displaced fracture of unspecified tibial spine...
# 1026  S82113H  Displaced fracture of unspecified tibial spine...
# 1027  S82113J  Displaced fracture of unspecified tibial spine...
# 1028  S82113K  Displaced fracture of unspecified tibial spine...
# 1029  S82113M  Displaced fracture of unspecified tibial spine...
# 1030  S82113N  Displaced fracture of unspecified tibial spine...
# 1031  S82113P  Displaced fracture of unspecified tibial spine...
# 1032  S82113Q  Displaced fracture of unspecified tibial spine...
# 1033  S82113R  Displaced fracture of unspecified tibial spine...
# 1034  S82113S  Displaced fracture of unspecified tibial spine...
# 1035   S82114        Nondisplaced fracture of right tibial spine
# 1036  S82114A  Nondisplaced fracture of right tibial spine, i...
# 1037  S82114B  Nondisplaced fracture of right tibial spine, i...
# 1038  S82114C  Nondisplaced fracture of right tibial spine, i...
# 1039  S82114D  Nondisplaced fracture of right tibial spine, s...
# 1040  S82114E  Nondisplaced fracture of right tibial spine, s...
# 1041  S82114F  Nondisplaced fracture of right tibial spine, s...
# 1042  S82114G  Nondisplaced fracture of right tibial spine, s...
# 1043  S82114H  Nondisplaced fracture of right tibial spine, s...
# 1044  S82114J  Nondisplaced fracture of right tibial spine, s...
# 1045  S82114K  Nondisplaced fracture of right tibial spine, s...
# 1046  S82114M  Nondisplaced fracture of right tibial spine, s...
# 1047  S82114N  Nondisplaced fracture of right tibial spine, s...
# 1048  S82114P  Nondisplaced fracture of right tibial spine, s...
# 1049  S82114Q  Nondisplaced fracture of right tibial spine, s...
# 1050  S82114R  Nondisplaced fracture of right tibial spine, s...
# 1051  S82114S  Nondisplaced fracture of right tibial spine, s...
# 1052   S82115         Nondisplaced fracture of left tibial spine
# 1053  S82115A  Nondisplaced fracture of left tibial spine, in...
# 1054  S82115B  Nondisplaced fracture of left tibial spine, in...
# 1055  S82115C  Nondisplaced fracture of left tibial spine, in...
# 1056  S82115D  Nondisplaced fracture of left tibial spine, su...
# 1057  S82115E  Nondisplaced fracture of left tibial spine, su...
# 1058  S82115F  Nondisplaced fracture of left tibial spine, su...
# 1059  S82115G  Nondisplaced fracture of left tibial spine, su...
# 1060  S82115H  Nondisplaced fracture of left tibial spine, su...
# 1061  S82115J  Nondisplaced fracture of left tibial spine, su...
# 1062  S82115K  Nondisplaced fracture of left tibial spine, su...
# 1063  S82115M  Nondisplaced fracture of left tibial spine, su...
# 1064  S82115N  Nondisplaced fracture of left tibial spine, su...
# 1065  S82115P  Nondisplaced fracture of left tibial spine, su...
# 1066  S82115Q  Nondisplaced fracture of left tibial spine, su...
# 1067  S82115R  Nondisplaced fracture of left tibial spine, su...
# 1068  S82115S  Nondisplaced fracture of left tibial spine, se...
# 1069   S82116  Nondisplaced fracture of unspecified tibial spine
# 1070  S82116A  Nondisplaced fracture of unspecified tibial sp...
# 1071  S82116B  Nondisplaced fracture of unspecified tibial sp...
# 1072  S82116C  Nondisplaced fracture of unspecified tibial sp...
# 1073  S82116D  Nondisplaced fracture of unspecified tibial sp...
# 1074  S82116E  Nondisplaced fracture of unspecified tibial sp...
# 1075  S82116F  Nondisplaced fracture of unspecified tibial sp...
# 1076  S82116G  Nondisplaced fracture of unspecified tibial sp...
# 1077  S82116H  Nondisplaced fracture of unspecified tibial sp...
# 1078  S82116J  Nondisplaced fracture of unspecified tibial sp...
# 1079  S82116K  Nondisplaced fracture of unspecified tibial sp...
# 1080  S82116M  Nondisplaced fracture of unspecified tibial sp...
# 1081  S82116N  Nondisplaced fracture of unspecified tibial sp...
# 1082  S82116P  Nondisplaced fracture of unspecified tibial sp...
# 1083  S82116Q  Nondisplaced fracture of unspecified tibial sp...
# 1084  S82116R  Nondisplaced fracture of unspecified tibial sp...
# 1085  S82116S  Nondisplaced fracture of unspecified tibial sp...
# 1086    T8463  Infection and inflammatory reaction due to int...
# 1087  T8463XA  Infection and inflammatory reaction due to int...
# 1088  T8463XD  Infection and inflammatory reaction due to int...
# 1089  T8463XS  Infection and inflammatory reaction due to int...
# 1090   T85112  Breakdown (mechanical) of implanted electronic...
# 1091  T85112A  Breakdown (mechanical) of implanted electronic...
# 1092  T85112D  Breakdown (mechanical) of implanted electronic...
# 1093  T85112S  Breakdown (mechanical) of implanted electronic...
# 1094   T85122  Displacement of implanted electronic neurostim...
# 1095  T85122A  Displacement of implanted electronic neurostim...
# 1096  T85122D  Displacement of implanted electronic neurostim...
# 1097  T85122S  Displacement of implanted electronic neurostim...
# 1098   T85192  Other mechanical complication of implanted ele...
# 1099  T85192A  Other mechanical complication of implanted ele...
# 1100  T85192D  Other mechanical complication of implanted ele...
# 1101  T85192S  Other mechanical complication of implanted ele...
# 1102   T85610  Breakdown (mechanical) of cranial or spinal in...
# 1103  T85610A  Breakdown (mechanical) of cranial or spinal in...
# 1104  T85610D  Breakdown (mechanical) of cranial or spinal in...
# 1105  T85610S  Breakdown (mechanical) of cranial or spinal in...
# 1106   T85620  Displacement of cranial or spinal infusion cat...
# 1107  T85620A  Displacement of cranial or spinal infusion cat...
# 1108  T85620D  Displacement of cranial or spinal infusion cat...
# 1109  T85620S  Displacement of cranial or spinal infusion cat...
# 1110   T85630     Leakage of cranial or spinal infusion catheter
# 1111  T85630A  Leakage of cranial or spinal infusion catheter...
# 1112  T85630D  Leakage of cranial or spinal infusion catheter...
# 1113  T85630S  Leakage of cranial or spinal infusion catheter...
# 1114   T85690  Other mechanical complication of cranial or sp...
# 1115  T85690A  Other mechanical complication of cranial or sp...
# 1116  T85690D  Other mechanical complication of cranial or sp...
# 1117  T85690S  Other mechanical complication of cranial or sp...
# 1118   T85733  Infection and inflammatory reaction due to imp...
# 1119  T85733A  Infection and inflammatory reaction due to imp...
# 1120  T85733D  Infection and inflammatory reaction due to imp...
# 1121  T85733S  Infection and inflammatory reaction due to imp...
# 1122   T85735  Infection and inflammatory reaction due to cra...
# 1123  T85735A  Infection and inflammatory reaction due to cra...
# 1124  T85735D  Infection and inflammatory reaction due to cra...
# 1125  T85735S  Infection and inflammatory reaction due to cra...
# 1126     V452    Presence of cerebrospinal fluid drainage device
# 1127    V5302  Fitting and adjustment of neuropacemaker (brai...
# 1128    V9031                   Retained animal quills or spines
# 1129      W60  Contact with nonvenomous plant thorns and spin...
# 1130  W60XXXA  Contact with nonvenomous plant thorns and spin...
# 1131  W60XXXD  Contact with nonvenomous plant thorns and spin...
# 1132  W60XXXS  Contact with nonvenomous plant thorns and spin...
# 1133    Z1831                   Retained animal quills or spines
# 1134    Z4541  Encounter for adjustment and management of cer...
# 1135     Z982    Presence of cerebrospinal fluid drainage device

# %%
#Create a table(spinal_icd_list) in the SQL database that contains all the spinal number for linking; 
import sqlite3

# Connect to the local SQLite database
conn = sqlite3.connect('e:/mimic.db')
cur = conn.cursor()

# Create the new table using the SQL command
create_table_sql = """
CREATE TABLE spinal_icd_list AS
SELECT
    icd_code,
    long_title
FROM
    d_icd_diagnoses
WHERE
    LOWER(long_title) LIKE '%spinal%'
    OR LOWER(long_title) LIKE '%spine%'
    OR LOWER(long_title) LIKE '%vertebral%'
ORDER BY
    icd_code;
"""
cur.executescript(create_table_sql)
conn.commit()
conn.close()

# %%
# Query #1.
# Connect to (or create) a database file (Inital table with ICU patients that have spinal diagnosis, all 5,290 there could be
# multiple records as one patient can have multiple diagnosis.
# This is our driving table and contains all records related to indivdual who end up with spinal injures in the Intensive Care unit;
# The key is 5290 observation and that should not expand or decrease when adding more elements to the driving ICU patients table
# that have spinal chord related issues.

import sqlite3

# Connect to the local SQLite database
conn = sqlite3.connect('e:/mimic.db')
cur = conn.cursor()

# Create the new table using the SQL command
create_table_sql = """
CREATE TABLE ICU_SPINAL_PATIENT_5290 AS
SELECT
    i.subject_id,
    i.hadm_id,
    i.stay_id,
    i.first_careunit,
    i.last_careunit,
    i.intime,
    i.outtime,
    i.los,
    d.icd_code,
    s.long_title
FROM 
    icustays AS i
JOIN 
    diagnoses_icd AS d 
    ON i.hadm_id = d.hadm_id
JOIN 
    spinal_icd_list AS s 
    ON d.icd_code = s.icd_code
ORDER BY 
    i.subject_id, i.intime;
"""

cur.executescript(create_table_sql)
conn.commit()
conn.close()

# %%
# Query #2
# add to the ICU patient with additional columns such as gender, race, martial status,etc.
# Also if you see below the table and each characteristics and what is being added from the diffrent tables.
# Also as you can see we added the ICUSTAY table to the DIAGNOSTIC table and then to the SPINAL_ICD table then to the PATIENT table was 
# because there was not way to join the ICUSTAY table directly to the PATIENT table;
# See below, note that the last join was a left join so that not records were dropped due to the Pateint table possibly not having records 
# that matched up. 5,290 Observation was maintained.
import sqlite3

# Connect to the local SQLite database
conn = sqlite3.connect('e:/mimic.db')
cur = conn.cursor()

# Create the new table using the SQL command
create_table_sql = """
CREATE TABLE ICU_SPINAL_PATIENT_FEATURES AS
SELECT 
    i.subject_id,              -- ICU patient identifier
    i.hadm_id,                 -- Hospital admission ID
    i.stay_id,                 -- ICU stay ID
    i.intime,                  -- ICU admission time
    i.outtime,                 -- ICU discharge time
    i.los,                     -- ICU Length of Stay (target)
    d.icd_code,                -- ICD code from the diagnoses table
    s.long_title,              -- Description for the ICD code (spinal-related)
    p.gender,                  -- Demographic: Gender from the patients table
    p.anchor_age,              -- Age of the Client
    p.dod,                     -- Date of Death or Blank.
    a.admission_type,          -- Admission type (e.g., emergency, urgent)
    a.admission_location,      -- Location from which the patient was admitted
    a.insurance,               -- Insurance information (proxy for socioeconomic status)
    a.marital_status,          -- Marital status
    a.race                     -- Race
FROM icustays i
JOIN diagnoses_icd d 
  ON i.hadm_id = d.hadm_id
JOIN spinal_icd_list s 
  ON d.icd_code = s.icd_code
LEFT JOIN patient p 
  ON i.subject_id = p.subject_id
LEFT JOIN admissions a 
  ON i.hadm_id = a.hadm_id;
"""
cur.executescript(create_table_sql)
conn.commit()
conn.close()

# %%
# Understand one of the other tables we wanted to join. EDA, self learning/exploratory. 
# we are now using the function read_sql_query making code more readable, smaller, and consistent. 
# We are lookin to add more reading usally done by Nurses such as heartrate, etc.
# Note that there are close to 28 millions rows and multiples reading for each client.
# We will need to make sure that we transpose the data for the columns added and make sure
# we maintain the magical 5,290 Oberservation not increasing or decreasing the records.

conn = sqlite3.connect("e:/mimic.db")

# Run a SQL query

query = """
SELECT 
    ce.itemid,
    di.label,
    di.abbreviation,
    di.category,
    ce.valuenum,
    ce.charttime
FROM chartevents ce
JOIN d_items di ON ce.itemid = di.itemid
WHERE ce.itemid IN (220045, 227969, 220210, 220277)
ORDER BY ce.charttime;
"""

#SELECT * FROM diagnosis_icd where icd_code  limit 5;"
result_df = pd.read_sql_query(query, conn)

# Display the query result
#print(result_df)
explore_dataframe(result_df)

conn.close()
# Out:
# --------------- DataFrame Exploration Summary ---------------
#
# Number of records (rows): 27949612
# Number of columns: 6
#
# Column Names:
# Index(['itemid', 'label', 'abbreviation', 'category', 'valuenum', 'charttime'], dtype='object')
#
# First 5 rows of the DataFrame:
#    itemid                        label     abbreviation  \
# 0  220045                   Heart Rate               HR
# 1  220210             Respiratory Rate               RR
# 2  220277  O2 saturation pulseoxymetry             SpO2
# 3  227969              Safety Measures  Safety Measures
# 4  227969              Safety Measures  Safety Measures
#
#                     category  valuenum            charttime
# 0        Routine Vital Signs      94.0  2110-01-11 12:42:00
# 1                Respiratory      13.0  2110-01-11 12:42:00
# 2                Respiratory     100.0  2110-01-11 12:42:00
# 3  Restraint/Support Systems       NaN  2110-01-11 12:45:00
# 4  Restraint/Support Systems       NaN  2110-01-11 12:45:00
#
# Last 5 rows of the DataFrame:
#           itemid                        label abbreviation  \
# 27949607  220210             Respiratory Rate           RR
# 27949608  220277  O2 saturation pulseoxymetry         SpO2
# 27949609  220045                   Heart Rate           HR
# 27949610  220210             Respiratory Rate           RR
# 27949611  220277  O2 saturation pulseoxymetry         SpO2
#
#                      category  valuenum            charttime
# 27949607          Respiratory      22.0  2211-11-11 13:00:00
# 27949608          Respiratory      96.0  2211-11-11 13:00:00
# 27949609  Routine Vital Signs      94.0  2211-11-11 14:00:00
# 27949610          Respiratory      25.0  2211-11-11 14:00:00
# 27949611          Respiratory      92.0  2211-11-11 14:00:00
#
# Information about DataFrame (columns and data types):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27949612 entries, 0 to 27949611
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   itemid        int64
#  1   label         object
#  2   abbreviation  object
#  3   category      object
#  4   valuenum      float64
#  5   charttime     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.2+ GB
# None
#
# Summary statistics for numerical columns:
#              itemid      valuenum
# count  2.794961e+07  1.917894e+07
# mean   2.226218e+05  7.096602e+01
# std    3.616911e+03  5.241255e+03
# min    2.200450e+05 -2.413950e+05
# 25%    2.202100e+05  2.300000e+01
# 50%    2.202770e+05  8.400000e+01
# 75%    2.279690e+05  9.700000e+01
# max    2.279690e+05  1.000000e+07
#
# Number of missing (NaN) values per column:
# itemid                0
# label                 0
# abbreviation          0
# category              0
# valuenum        8770670
# charttime             0
# dtype: int64
#
# Number of non-null (non-NaN) values per column:
# itemid          27949612
# label           27949612
# abbreviation    27949612
# category        27949612
# valuenum        19178942
# charttime       27949612
# dtype: int64
#
# --------------- End of Exploration Summary ---------------

# %%
# Query #3
# Columns: We use  for grouping.
# Aggregation: We compute the 
# average (), minimum (), and maximum () values from the  column for those records where , which is assumed to correspond to the heart rate measure.
# Grouping: The aggregation is done per ICU stay ().
# Using summary functions above to make sure we transpose the data and given there are many many records related to each client due to frequency
# of vitals taken for each patient we had to use the above summary functions to get some key attributes that might help us with the task.
# Description of each field is defined below by using comments.

"""
load_csv_to_sqlite(
    file_path="c:/stefan/icu/caregiver.csv.gz",
    db_path="e:/mimic.db",
    table_name="caregiver"
)
"""
import sqlite3

# Connect to the local SQLite database
conn = sqlite3.connect('e:/mimic.db')
cur = conn.cursor()

# Create the new table using the SQL command
create_table_sql = """
-- Create a new table that enriches ICU_SPINAL_PATIENT_FEATURES with aggregated vital sign measurements
CREATE TABLE ICU_SPINAL_PATIENT_FEATURES_VITALS AS
SELECT 
    -- Fields from the base table (ICU_SPINAL_PATIENT_FEATURES) with 1,136 rows
    f.subject_id,              -- Unique patient identifier
    f.hadm_id,                 -- Hospital admission identifier
    f.stay_id,                 -- ICU stay identifier
    f.intime,                  -- ICU admission time
    f.outtime,                 -- ICU discharge time
    f.los,                     -- ICU Length of Stay (target variable)
    f.icd_code,                -- ICD code from the initial diagnosis
    f.long_title,              -- Descriptive diagnosis (spinal-related)
    f.gender,                  -- Patient gender
    f.anchor_age,              -- Age of the Client
    f.dod,                     -- Date of Death or Blank.
    f.admission_type,          -- Type of admission (e.g., emergency, elective)
    f.admission_location,      -- Where the patient was admitted from
    f.insurance,               -- Insurance information (socioeconomic indicator)
    f.marital_status,          -- Marital status
    f.race,                    -- Patient race
    -- Aggregated vital signs from chartevents:
    ce.avg_hr,                 -- Average Heart Rate (itemid 220045)
    ce.min_hr,                 -- Minimum Heart Rate
    ce.max_hr,                 -- Maximum Heart Rate
    ce.avg_rr,                 -- Average Respiratory Rate (itemid 220210)
    ce.min_rr,                 -- Minimum Respiratory Rate
    ce.max_rr,                 -- Maximum Respiratory Rate
    ce.avg_SpO2,               -- Average Oxygen Saturation (SpO2) (itemid 220277)
    ce.min_SpO2,               -- Minimum Oxygen Saturation
    ce.max_SpO2                -- Maximum Oxygen Saturation
FROM ICU_SPINAL_PATIENT_FEATURES f
-- LEFT JOIN ensures that every row from the 1,136-row base table is preserved, even if no vital data is present
LEFT JOIN (
    -- Aggregates vital sign measurements from chartevents per ICU stay (stay_id)
    SELECT 
        stay_id,  -- Grouping key (matches ICU stay identifier)
        -- Aggregated measures for Heart Rate (itemid 220045)
        AVG(CASE WHEN itemid = 220045 THEN valuenum END) AS avg_hr,
        MIN(CASE WHEN itemid = 220045 THEN valuenum END) AS min_hr,
        MAX(CASE WHEN itemid = 220045 THEN valuenum END) AS max_hr,
        -- Aggregated measures for Respiratory Rate (itemid 220210)
        AVG(CASE WHEN itemid = 220210 THEN valuenum END) AS avg_rr,
        MIN(CASE WHEN itemid = 220210 THEN valuenum END) AS min_rr,
        MAX(CASE WHEN itemid = 220210 THEN valuenum END) AS max_rr,
        -- Aggregated measures for Oxygen Saturation (SpO2) (itemid 220277)
        AVG(CASE WHEN itemid = 220277 THEN valuenum END) AS avg_SpO2,
        MIN(CASE WHEN itemid = 220277 THEN valuenum END) AS min_SpO2,
        MAX(CASE WHEN itemid = 220277 THEN valuenum END) AS max_SpO2
    FROM chartevents
    WHERE itemid IN (220045, 220210, 220277)  -- Filter for the selected vital sign itemids
    GROUP BY stay_id
) ce
ON f.stay_id = ce.stay_id;  -- Join aggregated results by ICU stay identifier
"""
cur.executescript(create_table_sql)
conn.commit()
conn.close()

# %%
#Query #4 is very similar to query #3 as agian we used LABATORY table to add key attirbutes
#to the main ICUTABLE (summary again due to one to many realtionship as we want to maintain the magical 5290 records)
#Items such as white blood cell count.

import sqlite3

# Connect to the local SQLite database
conn = sqlite3.connect('e:/mimic.db')
cur = conn.cursor()

# Create the new table using the SQL command
create_table_sql = """
CREATE TABLE ICU_SPINAL_PATIENT_FEATURES_VITALS_EXT AS
SELECT 
    -- Basic Patient and ICU Admission Details:
    f.subject_id,              -- Unique patient identifier
    f.hadm_id,                 -- Hospital admission identifier
    f.stay_id,                 -- ICU stay identifier
    f.intime,                  -- ICU admission timestamp
    f.outtime,                 -- ICU discharge timestamp
    f.los,                     -- ICU length of stay (target variable)
    f.icd_code,                -- ICD code for spinal diagnosis
    f.long_title,              -- Detailed description of the spinal diagnosis
    f.gender,                  -- Patient gender
    f.anchor_age,              -- Patient age (from the 'anchor_age' field)
    f.dod,                     -- Date of death (if applicable)
    f.admission_type,          -- Type of admission (e.g., emergency, elective)
    f.admission_location,      -- Source/location of ICU admission
    f.insurance,               -- Insurance information (proxy for socioeconomic status)
    f.marital_status,          -- Marital status of the patient
    f.race,                    -- Patient race

    -- Vital Sign Aggregates from chartevents:
    ce.avg_hr,                 -- Average heart rate (itemid 220045) during ICU stay
    ce.min_hr,                 -- Minimum heart rate recorded during ICU stay
    ce.max_hr,                 -- Maximum heart rate recorded during ICU stay
    ce.avg_rr,                 -- Average respiratory rate (itemid 220210) during ICU stay
    ce.min_rr,                 -- Minimum respiratory rate recorded during ICU stay
    ce.max_rr,                 -- Maximum respiratory rate recorded during ICU stay
    ce.avg_SpO2,               -- Average oxygen saturation (SpO₂, itemid 220277) during ICU stay
    ce.min_SpO2,               -- Minimum oxygen saturation recorded during ICU stay
    ce.max_SpO2,               -- Maximum oxygen saturation recorded during ICU stay

    -- Additional Laboratory Values from labevents:
    lab.avg_creatinine,        -- Average serum creatinine (itemid 50912) during hospitalization
    lab.min_creatinine,        -- Minimum serum creatinine recorded
    lab.max_creatinine,        -- Maximum serum creatinine recorded
    labwbc.avg_wbc,            -- Average white blood cell (WBC) count (example: itemid 51300)
    labwbc.min_wbc,            -- Minimum WBC count recorded
    labwbc.max_wbc,            -- Maximum WBC count recorded

    -- Derived Timing Features from ICU Admission Time:
    strftime('%H', f.intime) AS admission_hour,    -- Hour of ICU admission (00 to 23)
    strftime('%w', f.intime) AS admission_dayofweek, -- Day-of-week (0 = Sunday, 6 = Saturday)
    CASE 
        WHEN strftime('%w', f.intime) IN ('0','6') THEN 1  -- Flag for weekend admission (1=Yes)
        ELSE 0 
    END AS weekend_admission,

    -- Comorbidity Indicator:
    dx.dx_count                -- Count of distinct diagnoses (proxy for comorbidity burden)

FROM ICU_SPINAL_PATIENT_FEATURES f

-- LEFT JOIN aggregated vital sign measurements from chartevents by ICU stay:
LEFT JOIN (
    SELECT 
        stay_id,
        -- Heart Rate (itemid 220045):
        AVG(CASE WHEN itemid = 220045 THEN valuenum END) AS avg_hr,
        MIN(CASE WHEN itemid = 220045 THEN valuenum END) AS min_hr,
        MAX(CASE WHEN itemid = 220045 THEN valuenum END) AS max_hr,
        -- Respiratory Rate (itemid 220210):
        AVG(CASE WHEN itemid = 220210 THEN valuenum END) AS avg_rr,
        MIN(CASE WHEN itemid = 220210 THEN valuenum END) AS min_rr,
        MAX(CASE WHEN itemid = 220210 THEN valuenum END) AS max_rr,
        -- Oxygen Saturation (SpO₂, itemid 220277):
        AVG(CASE WHEN itemid = 220277 THEN valuenum END) AS avg_SpO2,
        MIN(CASE WHEN itemid = 220277 THEN valuenum END) AS min_SpO2,
        MAX(CASE WHEN itemid = 220277 THEN valuenum END) AS max_SpO2
    FROM chartevents
    WHERE itemid IN (220045, 220210, 220277)  -- Include only the selected vital sign itemids
    GROUP BY stay_id
) ce
    ON f.stay_id = ce.stay_id  -- Join on ICU stay identifier to match each patient's ICU stay

-- LEFT JOIN aggregated serum creatinine values from labevents:
LEFT JOIN (
    SELECT 
        hadm_id,
        AVG(CASE WHEN itemid = 50912 THEN valuenum END) AS avg_creatinine,
        MIN(CASE WHEN itemid = 50912 THEN valuenum END) AS min_creatinine,
        MAX(CASE WHEN itemid = 50912 THEN valuenum END) AS max_creatinine
    FROM labevents
    WHERE itemid = 50912
    GROUP BY hadm_id
) lab
    ON f.hadm_id = lab.hadm_id  -- Join on hospital admission identifier

-- LEFT JOIN aggregated WBC count values from labevents:
LEFT JOIN (
    SELECT 
        hadm_id,
        AVG(CASE WHEN itemid = 51300 THEN valuenum END) AS avg_wbc,
        MIN(CASE WHEN itemid = 51300 THEN valuenum END) AS min_wbc,
        MAX(CASE WHEN itemid = 51300 THEN valuenum END) AS max_wbc
    FROM labevents
    WHERE itemid = 51300
    GROUP BY hadm_id
) labwbc
    ON f.hadm_id = labwbc.hadm_id  -- Join on hospital admission identifier

-- LEFT JOIN to derive a comorbidity indicator by counting distinct ICD codes:
LEFT JOIN (
    SELECT 
        hadm_id,
        COUNT(DISTINCT icd_code) AS dx_count
    FROM diagnoses_icd
    GROUP BY hadm_id
) dx 
    ON f.hadm_id = dx.hadm_id;  -- Join on hospital admission identifier
"""
cur.executescript(create_table_sql)
conn.commit()
conn.close()

# %%
# extract above final table to a .CSV file for sharing;
# Out:
# Data successfully exported to ICU_SPINAL_PATIENT_FEATURES_VITALS_EXT.csv

# %%
# Below is the final table exported out 5,290 records so our team can now do the Analysis on this table.
# For us to do analysis we need at lease 1K of records and we were lucky to have over 5K or records for analysis.

import sqlite3
import csv

# Path to your SQLite database on e drive
db_path = r"e:\mimic.db"

# Table name (and CSV file name)
table_name = "ICU_SPINAL_PATIENT_FEATURES_VITALS_EXT"

# Output CSV file path on e drive
csv_file = r"e:\ICU_SPINAL_PATIENT_FEATURES_VITALS_EXT.csv"

# Connect to the SQLite database
conn = sqlite3.connect(db_path)

# Create a cursor object
cursor = conn.cursor()

# Query to fetch all data from the table
query = f"SELECT * FROM {table_name}"

try:
    # Execute the query
    cursor.execute(query)

    # Fetch all rows
    rows = cursor.fetchall()

    # Get column names
    column_names = [description[0] for description in cursor.description]

    # Write data to CSV file
    with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)

        # Write column headers
        writer.writerow(column_names)

        # Write rows
        writer.writerows(rows)

    print(f"Data successfully exported to {csv_file}")
except sqlite3.Error as e:
    print(f"An error occurred: {e}")
finally:
    # Close the connection
    conn.close()
# Out:
# Data successfully exported to e:\ICU_SPINAL_PATIENT_FEATURES_VITALS_EXT.csv
